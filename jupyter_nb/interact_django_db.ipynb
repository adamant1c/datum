# %%
import pandas as pd
import sys, os, django
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

# %%
from dieta.models import Tipo_pasto
from dieta.models import Ingrediente_Piatto

# %%
Tipo_pasto.objects.all()
# Out:
# <QuerySet [<Tipo_pasto: Colazione>, <Tipo_pasto: Merenda>, <Tipo_pasto: Pranzo>, <Tipo_pasto: Cena>]>

# %%
tipo_li = {'tipo': ['gi1','g12','gi3','gi4']}

df = pd.DataFrame(tipo_li)

print (df)
# Out:
#   tipo
# 0  gi1
# 1  g12
# 2  gi3
# 3  gi4

# %%
for i in range(len(df)):
   Tipo_pasto(tipo = df.iloc[i][0]).save()

# %%
Tipo_pasto.objects.all()
# Out:
# <QuerySet [<Tipo_pasto: Colazione>, <Tipo_pasto: Merenda>, <Tipo_pasto: Pranzo>, <Tipo_pasto: Cena>, <Tipo_pasto: gi1>, <Tipo_pasto: g12>, <Tipo_pasto: gi3>, <Tipo_pasto: gi4>]>

# %%
Tipo_pasto.objects.get(pk = 6)
# Out:
# ---------------------------------------------------------------------------
# DoesNotExist                              Traceback (most recent call last)
# <ipython-input-98-6170673aa2ea> in <module>
# ----> 1 Tipo_pasto.objects.get(pk = 6)
#
# ~/.local/lib/python3.7/site-packages/django/db/models/manager.py in manager_method(self, *args, **kwargs)
#      83         def create_method(name, method):
#      84             def manager_method(self, *args, **kwargs):
# ---> 85                 return getattr(self.get_queryset(), name)(*args, **kwargs)
#      86             manager_method.__name__ = method.__name__
#      87             manager_method.__doc__ = method.__doc__
#
# ~/.local/lib/python3.7/site-packages/django/db/models/query.py in get(self, *args, **kwargs)
#     435             raise self.model.DoesNotExist(
#     436                 "%s matching query does not exist." %
# --> 437                 self.model._meta.object_name
#     438             )
#     439         raise self.model.MultipleObjectsReturned(
#
# DoesNotExist: Tipo_pasto matching query does not exist.

# %%
for i in range(6,9,1):
    Tipo_pasto.objects.get(pk = i).delete()
# Out:
# ---------------------------------------------------------------------------
# DoesNotExist                              Traceback (most recent call last)
# <ipython-input-99-3204830d7d74> in <module>
#       1 for i in range(6,9,1):
# ----> 2     Tipo_pasto.objects.get(pk = i).delete()
#
# ~/.local/lib/python3.7/site-packages/django/db/models/manager.py in manager_method(self, *args, **kwargs)
#      83         def create_method(name, method):
#      84             def manager_method(self, *args, **kwargs):
# ---> 85                 return getattr(self.get_queryset(), name)(*args, **kwargs)
#      86             manager_method.__name__ = method.__name__
#      87             manager_method.__doc__ = method.__doc__
#
# ~/.local/lib/python3.7/site-packages/django/db/models/query.py in get(self, *args, **kwargs)
#     435             raise self.model.DoesNotExist(
#     436                 "%s matching query does not exist." %
# --> 437                 self.model._meta.object_name
#     438             )
#     439         raise self.model.MultipleObjectsReturned(
#
# DoesNotExist: Tipo_pasto matching query does not exist.

# %%
Tipo_pasto.objects.all()

# %% [markdown]
# class Piatti(models.Model):
#     nome_piatto=models.CharField(max_length=30)
#     ingredienti=models.ManyToManyField(Ingrediente)
#     costo_preparazione = models.IntegerField(blank=True, null=True)
#     categoria = models.IntegerField(blank=True, null=True)
#     descrizione=models.TextField(blank=True, null=True)
#     tempo_preparazione = models.IntegerField(blank=True, null=True)
#     tempo_cottura = models.IntegerField(blank=True, null=True)
#     ricetta=models.TextField(blank=True, null=True)
#     Calorie_kcal=models.FloatField(blank=True, null=True)
#     Carboidrati_g=models.FloatField(blank=True, null=True)
#     Zuccheri_g=models.FloatField(blank=True, null=True)
#     Grassi_g=models.FloatField(blank=True, null=True)
#     Grassi_Saturi_g=models.FloatField(blank=True, null=True)
#     Fibre_g=models.FloatField(blank=True, null=True)
#     Colesterolo_m=models.FloatField(blank=True, null=True)
#     Sodio_mg=models.FloatField(blank=True, null=True)

# %%
df_piatto=pd.read_csv("tab_piatto.csv")

# %%
df_piatto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2173 entries, 0 to 2172
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Nome_Piatto         2173 non-null   object
#  1   Costo_Preparazione  2173 non-null   int64
#  2   Categoria           2173 non-null   int64
#  3   Descrizione         2173 non-null   object
#  4   Tempo_Preparazione  2173 non-null   int64
#  5   Tempo_Cottura       2173 non-null   int64
#  6   Ricetta             2172 non-null   object
# dtypes: int64(4), object(3)
# memory usage: 93.4+ KB

# %%
df_piatto.head()
# Out:
#                                 Nome_Piatto  Costo_Preparazione  Categoria  \
# 0                     Biscotti alla paprika                   0          0
# 1  Bastoncini di pasta sfoglia al formaggio                   0          0
# 2                                 Brustengo                   1          0
# 3        Insalata tiepida di polpo e patate                   2          2
# 4              Insalata di daikon e gamberi                   2          0
#
#                                          Descrizione  Tempo_Preparazione  \
# 0  I biscotti alla paprika sono dei deliziosi boc...                  20
# 1  I bastoncini di pasta sfoglia al formaggio son...                  20
# 2  Farina, acqua e sale: una ricetta semplice que...                   5
# 3  L'insalata  tiepida di polpo e patate è un sec...                  20
# 4  L'insalata di daikon e gamberi è un antipasto ...                  25
#
#    Tempo_Cottura                                            Ricetta
# 0             20  Per preparare i biscotti alla paprika iniziate...
# 1              0  Per preparare i bastoncini di sfoglia al forma...
# 2             15  Per realizzare il brustengo, per prima cosa pr...
# 3             65  Per preparare l’insalata tiepida di polpo e pa...
# 4              0  Per realizzare l’insalata di daikon e gamberi ...

# %%
df_nutrizione=pd.read_csv("tab_nutrizione.csv")
df_nutrizione.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2173 entries, 0 to 2172
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Nome_Piatto      2173 non-null   object
#  1   Calorie_kcal     1704 non-null   float64
#  2   Carboidrati_g    1704 non-null   float64
#  3   Zuccheri_g       1704 non-null   float64
#  4   Grassi_g         1704 non-null   float64
#  5   Grassi Saturi_g  1704 non-null   float64
#  6   Fibre_g          1704 non-null   float64
#  7   Colesterolo_mg   1704 non-null   float64
#  8   Sodio_mg         1704 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 144.4+ KB

# %%
df_nutrizione.head()
# Out:
#                                 Nome_Piatto  Calorie_kcal  Carboidrati_g  \
# 0                     Biscotti alla paprika         117.0            8.1
# 1  Bastoncini di pasta sfoglia al formaggio         229.0           15.7
# 2                                 Brustengo         299.0           23.4
# 3        Insalata tiepida di polpo e patate         456.0           41.7
# 4              Insalata di daikon e gamberi         317.0            5.7
#
#    Zuccheri_g  Grassi_g  Grassi Saturi_g  Fibre_g  Colesterolo_mg  Sodio_mg
# 0         0.4       7.8             3.99      0.5            43.0      80.0
# 1         0.9      16.1             6.61      1.1            41.0     318.0
# 2         0.6      15.4             6.11      0.8            41.0    1365.0
# 3         5.1      19.5             3.54      4.1           162.0     836.0
# 4         5.1      28.1             5.32      2.7           157.0     611.0

# %% [markdown]
# class Ingrediente(models.Model):
#   Nome = models.CharField(max_length=22)
#   Metodo_Preparazione = models.CharField(max_length=22,blank=True, null=True)
#   Flag_istamina=models.BooleanField(null=True)
#   Flag_nichel=models.BooleanField(null=True)
#   Flag_ferro=models.BooleanField(null=True)
#   Composizione=models.TextField(blank=True, null=True)

# %%
df_ingredienti=pd.read_csv("tab_ingredienti_definitiva.csv")
df_ingredienti.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22392 entries, 0 to 22391
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Ingrediente      22392 non-null  object
#  1   Quantita         22392 non-null  object
#  2   Unita di misura  22392 non-null  object
#  3   Nome Piatto      22392 non-null  object
# dtypes: object(4)
# memory usage: 349.9+ KB

# %%
df_ingredienti.head()
# Out:
#                                    Ingrediente Quantita Unita di misura  \
# 0                                 Burro freddo      150               g
# 1                                    Farina 00      250               g
# 2                      Parmigiano Reggiano DOP      100               g
# 3                         Uova (circa 2 medie)      100               g
# 4   Lievito istantaneo per preparazioni salate        8               g
#
#              Nome Piatto
# 0  Biscotti alla paprika
# 1  Biscotti alla paprika
# 2  Biscotti alla paprika
# 3  Biscotti alla paprika
# 4  Biscotti alla paprika

# %%
df_piatto_tot=pd.merge(df_piatto,df_nutrizione,how='left',on='Nome_Piatto')

# %%
df_piatto_tot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2173 entries, 0 to 2172
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Nome_Piatto         2173 non-null   object
#  1   Costo_Preparazione  2173 non-null   int64
#  2   Categoria           2173 non-null   int64
#  3   Descrizione         2173 non-null   object
#  4   Tempo_Preparazione  2173 non-null   int64
#  5   Tempo_Cottura       2173 non-null   int64
#  6   Ricetta             2172 non-null   object
#  7   Calorie_kcal        1704 non-null   float64
#  8   Carboidrati_g       1704 non-null   float64
#  9   Zuccheri_g          1704 non-null   float64
#  10  Grassi_g            1704 non-null   float64
#  11  Grassi Saturi_g     1704 non-null   float64
#  12  Fibre_g             1704 non-null   float64
#  13  Colesterolo_mg      1704 non-null   float64
#  14  Sodio_mg            1704 non-null   float64
# dtypes: float64(8), int64(4), object(3)
# memory usage: 246.2+ KB

# %%
df_piatto_tot.head()
# Out:
#                                 Nome_Piatto  Costo_Preparazione  Categoria  \
# 0                     Biscotti alla paprika                   0          0
# 1  Bastoncini di pasta sfoglia al formaggio                   0          0
# 2                                 Brustengo                   1          0
# 3        Insalata tiepida di polpo e patate                   2          2
# 4              Insalata di daikon e gamberi                   2          0
#
#                                          Descrizione  Tempo_Preparazione  \
# 0  I biscotti alla paprika sono dei deliziosi boc...                  20
# 1  I bastoncini di pasta sfoglia al formaggio son...                  20
# 2  Farina, acqua e sale: una ricetta semplice que...                   5
# 3  L'insalata  tiepida di polpo e patate è un sec...                  20
# 4  L'insalata di daikon e gamberi è un antipasto ...                  25
#
#    Tempo_Cottura                                            Ricetta  \
# 0             20  Per preparare i biscotti alla paprika iniziate...
# 1              0  Per preparare i bastoncini di sfoglia al forma...
# 2             15  Per realizzare il brustengo, per prima cosa pr...
# 3             65  Per preparare l’insalata tiepida di polpo e pa...
# 4              0  Per realizzare l’insalata di daikon e gamberi ...
#
#    Calorie_kcal  Carboidrati_g  Zuccheri_g  Grassi_g  Grassi Saturi_g  \
# 0         117.0            8.1         0.4       7.8             3.99
# 1         229.0           15.7         0.9      16.1             6.61
# 2         299.0           23.4         0.6      15.4             6.11
# 3         456.0           41.7         5.1      19.5             3.54
# 4         317.0            5.7         5.1      28.1             5.32
#
#    Fibre_g  Colesterolo_mg  Sodio_mg
# 0      0.5            43.0      80.0
# 1      1.1            41.0     318.0
# 2      0.8            41.0    1365.0
# 3      4.1           162.0     836.0
# 4      2.7           157.0     611.0

# %%
from dieta.models import Piatti

# %% [markdown]
# nome_piatto=models.CharField(max_length=30)
#     ingredienti=models.ManyToManyField(Ingrediente_Piatto)
#     costo_preparazione = models.IntegerField(blank=True, null=True)
#     categoria = models.IntegerField(blank=True, null=True)
#     descrizione=models.TextField(blank=True, null=True)
#     tempo_preparazione = models.IntegerField(blank=True, null=True)
#     tempo_cottura = models.IntegerField(blank=True, null=True)
#     ricetta=models.TextField(blank=True, null=True)
#     Calorie_kcal=models.FloatField(blank=True, null=True)
#     Carboidrati_g=models.FloatField(blank=True, null=True)
#     Zuccheri_g=models.FloatField(blank=True, null=True)
#     Grassi_g=models.FloatField(blank=True, null=True)
#     Grassi_Saturi_g=models.FloatField(blank=True, null=True)
#     Fibre_g=models.FloatField(blank=True, null=True)
#     Colesterolo_m=models.FloatField(blank=True, null=True)
#     Sodio_mg=models.FloatField(blank=True, null=True)

# %%
df_piatto_tot.columns
# Out:
# Index(['Nome_Piatto', 'Costo_Preparazione', 'Categoria', 'Descrizione',
#        'Tempo_Preparazione', 'Tempo_Cottura', 'Ricetta', 'Calorie_kcal',
#        'Carboidrati_g', 'Zuccheri_g', 'Grassi_g', 'Grassi Saturi_g', 'Fibre_g',
#        'Colesterolo_mg', 'Sodio_mg'],
#       dtype='object')

# %%
for i in range(len(df_piatto_tot)):
   Piatti(nome_piatto = df_piatto_tot.iloc[i][0], 
         costo_preparazione = df_piatto_tot.iloc[i][1],categoria = df_piatto_tot.iloc[i][2],

          descrizione = df_piatto_tot.iloc[i][3], tempo_preparazione = df_piatto_tot.iloc[i][4],
         tempo_cottura = df_piatto_tot.iloc[i][5],ricetta = df_piatto_tot.iloc[i][6],
         Calorie_kcal= df_piatto_tot.iloc[i][7],Carboidrati_g= df_piatto_tot.iloc[i][8],
         Zuccheri_g= df_piatto_tot.iloc[i][9],Grassi_g= df_piatto_tot.iloc[i][10],
         Grassi_Saturi_g= df_piatto_tot.iloc[i][11],Fibre_g= df_piatto_tot.iloc[i][12],
         Colesterolo_m= df_piatto_tot.iloc[i][13],Sodio_mg= df_piatto_tot.iloc[i][14]).save()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-112-617ded9edc86> in <module>
#       8          Zuccheri_g= df_piatto_tot.iloc[i][9],Grassi_g= df_piatto_tot.iloc[i][10],
#       9          Grassi_Saturi_g= df_piatto_tot.iloc[i][11],Fibre_g= df_piatto_tot.iloc[i][12],
# ---> 10          Colesterolo_m= df_piatto_tot.iloc[i][13],Sodio_mg= df_piatto_tot.iloc[i][14]).save()
#      11
#
# ~/.local/lib/python3.7/site-packages/django/db/models/base.py in save(self, force_insert, force_update, using, update_fields)
#     725
#     726         self.save_base(using=using, force_insert=force_insert,
# --> 727                        force_update=force_update, update_fields=update_fields)
#     728     save.alters_data = True
#     729
#
# ~/.local/lib/python3.7/site-packages/django/db/models/base.py in save_base(self, raw, force_insert, force_update, using, update_fields)
#     763             updated = self._save_table(
#     764                 raw, cls, force_insert or parent_inserted,
# --> 765                 force_update, using, update_fields,
#     766             )
#     767         # Store the database on which the object was saved
#
# ~/.local/lib/python3.7/site-packages/django/db/models/base.py in _save_table(self, raw, cls, force_insert, force_update, using, update_fields)
#     866
#     867             returning_fields = meta.db_returning_fields
# --> 868             results = self._do_insert(cls._base_manager, using, fields, returning_fields, raw)
#     869             if results:
#     870                 for value, field in zip(results[0], returning_fields):
#
# ~/.local/lib/python3.7/site-packages/django/db/models/base.py in _do_insert(self, manager, using, fields, returning_fields, raw)
#     906         return manager._insert(
#     907             [self], fields=fields, returning_fields=returning_fields,
# --> 908             using=using, raw=raw,
#     909         )
#     910
#
# ~/.local/lib/python3.7/site-packages/django/db/models/manager.py in manager_method(self, *args, **kwargs)
#      83         def create_method(name, method):
#      84             def manager_method(self, *args, **kwargs):
# ---> 85                 return getattr(self.get_queryset(), name)(*args, **kwargs)
#      86             manager_method.__name__ = method.__name__
#      87             manager_method.__doc__ = method.__doc__
#
# ~/.local/lib/python3.7/site-packages/django/db/models/query.py in _insert(self, objs, fields, returning_fields, raw, using, ignore_conflicts)
#    1268         query = sql.InsertQuery(self.model, ignore_conflicts=ignore_conflicts)
#    1269         query.insert_values(fields, objs, raw=raw)
# -> 1270         return query.get_compiler(using=using).execute_sql(returning_fields)
#    1271     _insert.alters_data = True
#    1272     _insert.queryset_only = False
#
# ~/.local/lib/python3.7/site-packages/django/db/models/sql/compiler.py in execute_sql(self, returning_fields)
#    1414         with self.connection.cursor() as cursor:
#    1415             for sql, params in self.as_sql():
# -> 1416                 cursor.execute(sql, params)
#    1417             if not self.returning_fields:
#    1418                 return []
#
# ~/.local/lib/python3.7/site-packages/django/db/backends/utils.py in execute(self, sql, params)
#      96     def execute(self, sql, params=None):
#      97         with self.debug_sql(sql, params, use_last_executed_query=True):
# ---> 98             return super().execute(sql, params)
#      99
#     100     def executemany(self, sql, param_list):
#
# ~/.local/lib/python3.7/site-packages/django/db/backends/utils.py in execute(self, sql, params)
#      64
#      65     def execute(self, sql, params=None):
# ---> 66         return self._execute_with_wrappers(sql, params, many=False, executor=self._execute)
#      67
#      68     def executemany(self, sql, param_list):
#
# ~/.local/lib/python3.7/site-packages/django/db/backends/utils.py in _execute_with_wrappers(self, sql, params, many, executor)
#      73         for wrapper in reversed(self.db.execute_wrappers):
#      74             executor = functools.partial(wrapper, executor)
# ---> 75         return executor(sql, params, many, context)
#      76
#      77     def _execute(self, sql, params, *ignored_wrapper_args):
#
# ~/.local/lib/python3.7/site-packages/django/db/backends/utils.py in _execute(self, sql, params, *ignored_wrapper_args)
#      82                 return self.cursor.execute(sql)
#      83             else:
# ---> 84                 return self.cursor.execute(sql, params)
#      85
#      86     def _executemany(self, sql, param_list, *ignored_wrapper_args):
#
# ~/.local/lib/python3.7/site-packages/django/db/backends/sqlite3/base.py in execute(self, query, params)
#     421             return Database.Cursor.execute(self, query)
#     422         query = self.convert_query(query)
# --> 423         return Database.Cursor.execute(self, query, params)
#     424
#     425     def executemany(self, query, param_list):
#
# KeyboardInterrupt:

# %%
Piatti.objects.all()
# Out:
# <QuerySet [<Piatti: Biscotti alla paprika>, <Piatti: Bastoncini di pasta sfoglia al formaggio>, <Piatti: Brustengo>, <Piatti: Insalata tiepida di polpo e patate>, <Piatti: Insalata di daikon e gamberi>, <Piatti: Temaki di salmone>, <Piatti: Cozze alla tarantina>, <Piatti: Torta salata alla barbabietola>, <Piatti: Zucchine fritte>, <Piatti: Gamberi al cocco>, <Piatti: Avocado, uova e salmone>, <Piatti: Insalata di frutta>, <Piatti: Poke>, <Piatti: Crostino vegano>, <Piatti: Melanzane sott'olio>, <Piatti: Roselline di prosciutto crudo su fichi>, <Piatti: Hummus>, <Piatti: Caprese sfiziosa con salsa all'origano>, <Piatti: Supplì al telefono>, <Piatti: Crocchette di patate al forno>, '...(remaining elements truncated)...']>

# %%
A=Piatti.objects.get(pk = 2)

# %%
A.ricetta
# Out:
# 'Per preparare i biscotti alla paprika iniziate versando la farina ed il burro freddo tagliato a pezzetti in un mixer 1 . Regolate di sale e di pepe, unite il lievito 2 e azionate le lame per ottenere la sabbiatura. Trasferite il composto sabbioso sulla spianatoia 3 ,formate la classica fontana al centro 4 e unite la paprika, il parmigiano grattugiato 5 , date una mescolate e poi versate le uova mentre mescolate con la mano 6 .Passate ora ad impastare fino ad ottenere un panetto liscio ed omogeneo 7 . Copritelo con la pellicola trasparente e lasciatelo riposare in frigorifero per almeno mezzora 8 . Trascorso il tempo riprendete l’impasto e tiratelo su una spianatoia leggermente infarinata utilizzando il mattarello e ottenete una sfoglia di mezzo centimetro di spessore 9 .Con un coppapasta quadrato da 5x5cm ottenete i primi biscotti 10 : man mano disponeteli sulla leccarda rivestita con carta forno 11 . Prima di passare alla cottura, raccogliete i ritagli, impastateli nuovamente e metteteli a riposare, come prima, in frigo. Nel frattempo decorate i biscotti spennellandoli con un po’ d’uovo 12 .Poi cospargeteli con la granella di nocciole 13 e le mandole in lamelle 14 e cuocete la prima serie di biscotti in forno preriscaldato, in modalità statica, a 200° per circa 20 minuti 15 .Una volta cotti e leggermente dorati 16 lasciate raffreddare completamente i biscotti alla paprika su una gratella 17 prima di consumarli 18 .'

# %% [markdown]
# Nome = models.CharField(max_length=22)
#   Flag_istamina=models.BooleanField(null=True)
#   Flag_nichel=models.BooleanField(null=True)
#   Flag_ferro=models.BooleanField(null=True)
#   Note=models.TextField(blank=True, null=True)

# %%
from dieta.models import Ingrediente

# %%
# Out:
# (1866, {'dieta.Ingrediente': 1866})

# %%
for i in range(len(df_ingredienti)):
       Ingrediente(Nome = df_ingredienti.iloc[i][0]).save()

# %%
from dieta.models import Ingrediente_Piatto

# %%
df_ingredienti.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22392 entries, 0 to 22391
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Ingrediente      22392 non-null  object
#  1   Quantita         22392 non-null  object
#  2   Unita di misura  22392 non-null  object
#  3   Nome Piatto      22392 non-null  object
# dtypes: object(4)
# memory usage: 349.9+ KB

# %%
df_ingredienti[df_ingredienti.Quantita=='q.b.'].Quantita=0
# Out:
# /home/pi/.local/lib/python3.7/site-packages/pandas/core/generic.py:5159: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %% [markdown]
# ass Ingrediente_Piatto(models.Model):
#   Nome = models.ForeignKey(Ingrediente, on_delete=models.CASCADE)
#   Metodo_Preparazione = models.CharField(max_length=22,blank=True, null=True)
#   Quantità = models.FloatField()
#   UM=models.TextField(max_length=5,blank=True, null=True)

# %%
df_ingredienti.columns
# Out:
# Index(['Ingrediente', 'Quantita', 'Unita di misura', 'Nome Piatto'], dtype='object')

# %%
len(df_ingredienti)
# Out:
# 22392

# %%
for i in range(len(df_ingredienti)):
    new_ing=Ingrediente(Nome = df_ingredienti.iloc[i][0])
    new_ing.save()
    if(df_ingredienti.iloc[i][2].find('q.b.')>=0):
            qty=0
            #um=None
    else:
        try:
            qty=float(df_ingredienti.iloc[i][2])
        except:
            qty=0
    I_Pt=Ingrediente_Piatto(Nome = new_ing, 
       Quantità = qty,
       UM = df_ingredienti.iloc[i][2])
    I_Pt.save()
    try:
       Pt_ob=Piatti.objects.get(nome_piatto=df_ingredienti.iloc[i][3])
       #print(Pt_ob)
       Pt_ob.ingredienti.add(I_Pt)
    except:
        print("Nome Piatto not found:")
        print(df_ingredienti.iloc[i][3])
# Out:
# Nome Piatto not found:
# Biscotti alla paprika
# Nome Piatto not found:
# Biscotti alla paprika
# Nome Piatto not found:
# Biscotti alla paprika
# Nome Piatto not found:
# Biscotti alla paprika
# Nome Piatto not found:
# Biscotti alla paprika
# Nome Piatto not found:
# Biscotti alla paprika
# Nome Piatto not found:
# Biscotti alla paprika
# Nome Piatto not found:
# Biscotti alla paprika
# Nome Piatto not found:
# Biscotti alla paprika
# Nome Piatto not found:
# Biscotti alla paprika
# Nome Piatto not found:
# Biscotti alla paprika
# Nome Piatto not found:
# Bastoncini di pasta sfoglia al formaggio
# Nome Piatto not found:
# Bastoncini di pasta sfoglia al formaggio
# Nome Piatto not found:
# Bastoncini di pasta sfoglia al formaggio
# Nome Piatto not found:
# Bastoncini di pasta sfoglia al formaggio
# Nome Piatto not found:
# Bastoncini di pasta sfoglia al formaggio
# Nome Piatto not found:
# Bastoncini di pasta sfoglia al formaggio
# Nome Piatto not found:
# Bastoncini di pasta sfoglia al formaggio
# Nome Piatto not found:
# Bastoncini di pasta sfoglia al formaggio
# Nome Piatto not found:
# Brustengo
# Nome Piatto not found:
# Brustengo
# Nome Piatto not found:
# Brustengo
# Nome Piatto not found:
# Brustengo
# Nome Piatto not found:
# Brustengo
# Nome Piatto not found:
# Brustengo
# Nome Piatto not found:
# Insalata tiepida di polpo e patate
# Nome Piatto not found:
# Insalata tiepida di polpo e patate
# Nome Piatto not found:
# Insalata tiepida di polpo e patate
# Nome Piatto not found:
# Insalata tiepida di polpo e patate
# Nome Piatto not found:
# Insalata tiepida di polpo e patate
# Nome Piatto not found:
# Insalata tiepida di polpo e patate
# Nome Piatto not found:
# Insalata tiepida di polpo e patate
# Nome Piatto not found:
# Insalata tiepida di polpo e patate
# Nome Piatto not found:
# Insalata di daikon e gamberi
# Nome Piatto not found:
# Insalata di daikon e gamberi
# Nome Piatto not found:
# Insalata di daikon e gamberi
# Nome Piatto not found:
# Insalata di daikon e gamberi
# Nome Piatto not found:
# Insalata di daikon e gamberi
# Nome Piatto not found:
# Insalata di daikon e gamberi
# Nome Piatto not found:
# Insalata di daikon e gamberi
# Nome Piatto not found:
# Insalata di daikon e gamberi
# Nome Piatto not found:
# Insalata di daikon e gamberi
# Nome Piatto not found:
# Insalata di daikon e gamberi
# Nome Piatto not found:
# Insalata di daikon e gamberi
# Nome Piatto not found:
# Insalata di daikon e gamberi
# Nome Piatto not found:
# Insalata di daikon e gamberi
# Nome Piatto not found:
# Temaki di salmone
# Nome Piatto not found:
# Temaki di salmone
# Nome Piatto not found:
# Temaki di salmone
# Nome Piatto not found:
# Temaki di salmone
# Nome Piatto not found:
# Temaki di salmone
# Nome Piatto not found:
# Temaki di salmone
# Nome Piatto not found:
# Temaki di salmone
# Nome Piatto not found:
# Temaki di salmone
# Nome Piatto not found:
# Temaki di salmone
# Nome Piatto not found:
# Temaki di salmone
# Nome Piatto not found:
# Temaki di salmone
# Nome Piatto not found:
# Temaki di salmone
# Nome Piatto not found:
# Temaki di salmone
# Nome Piatto not found:
# Temaki di salmone
# Nome Piatto not found:
# Temaki di salmone
# Nome Piatto not found:
# Cozze alla tarantina
# Nome Piatto not found:
# Cozze alla tarantina
# Nome Piatto not found:
# Cozze alla tarantina
# Nome Piatto not found:
# Cozze alla tarantina
# Nome Piatto not found:
# Cozze alla tarantina
# Nome Piatto not found:
# Cozze alla tarantina
# Nome Piatto not found:
# Cozze alla tarantina
# Nome Piatto not found:
# Cozze alla tarantina
# Nome Piatto not found:
# Cozze alla tarantina
# Nome Piatto not found:
# Cozze alla tarantina
# Nome Piatto not found:
# Torta salata alla barbabietola
# Nome Piatto not found:
# Torta salata alla barbabietola
# Nome Piatto not found:
# Torta salata alla barbabietola
# Nome Piatto not found:
# Torta salata alla barbabietola
# Nome Piatto not found:
# Torta salata alla barbabietola
# Nome Piatto not found:
# Torta salata alla barbabietola
# Nome Piatto not found:
# Torta salata alla barbabietola
# Nome Piatto not found:
# Zucchine fritte
# Nome Piatto not found:
# Zucchine fritte
# Nome Piatto not found:
# Zucchine fritte
# Nome Piatto not found:
# Zucchine fritte
# Nome Piatto not found:
# Gamberi al cocco
# Nome Piatto not found:
# Gamberi al cocco
# Nome Piatto not found:
# Gamberi al cocco
# Nome Piatto not found:
# Gamberi al cocco
# Nome Piatto not found:
# Gamberi al cocco
# Nome Piatto not found:
# Gamberi al cocco
# Nome Piatto not found:
# Gamberi al cocco
# Nome Piatto not found:
# Gamberi al cocco
# Nome Piatto not found:
# Gamberi al cocco
# Nome Piatto not found:
# Gamberi al cocco
# Nome Piatto not found:
# Gamberi al cocco
# Nome Piatto not found:
# Gamberi al cocco
# Nome Piatto not found:
# Avocado. uova e salmone
# Nome Piatto not found:
# Avocado. uova e salmone
# Nome Piatto not found:
# Avocado. uova e salmone
# Nome Piatto not found:
# Avocado. uova e salmone
# Nome Piatto not found:
# Avocado. uova e salmone
# Nome Piatto not found:
# Avocado. uova e salmone
# Nome Piatto not found:
# Avocado. uova e salmone
# Nome Piatto not found:
# Avocado. uova e salmone
# Nome Piatto not found:
# Avocado. uova e salmone
# Nome Piatto not found:
# Insalata di frutta
# Nome Piatto not found:
# Insalata di frutta
# Nome Piatto not found:
# Insalata di frutta
# Nome Piatto not found:
# Insalata di frutta
# Nome Piatto not found:
# Insalata di frutta
# Nome Piatto not found:
# Insalata di frutta
# Nome Piatto not found:
# Insalata di frutta
# Nome Piatto not found:
# Insalata di frutta
# Nome Piatto not found:
# Insalata di frutta
# Nome Piatto not found:
# Insalata di frutta
# Nome Piatto not found:
# Poke
# Nome Piatto not found:
# Poke
# Nome Piatto not found:
# Poke
# Nome Piatto not found:
# Poke
# Nome Piatto not found:
# Poke
# Nome Piatto not found:
# Poke
# Nome Piatto not found:
# Poke
# Nome Piatto not found:
# Crostino vegano
# Nome Piatto not found:
# Crostino vegano
# Nome Piatto not found:
# Crostino vegano
# Nome Piatto not found:
# Crostino vegano
# Nome Piatto not found:
# Crostino vegano
# Nome Piatto not found:
# Crostino vegano
# Nome Piatto not found:
# Crostino vegano
# Nome Piatto not found:
# Crostino vegano
# Nome Piatto not found:
# Crostino vegano
# Nome Piatto not found:
# Crostino vegano
# Nome Piatto not found:
# Crostino vegano
# Nome Piatto not found:
# Crostino vegano
# Nome Piatto not found:
# Crostino vegano
# Nome Piatto not found:
# Melanzane sott'olio
# Nome Piatto not found:
# Melanzane sott'olio
# Nome Piatto not found:
# Melanzane sott'olio
# Nome Piatto not found:
# Melanzane sott'olio
# Nome Piatto not found:
# Melanzane sott'olio
# Nome Piatto not found:
# Roselline di prosciutto crudo su fichi
# Nome Piatto not found:
# Roselline di prosciutto crudo su fichi
# Nome Piatto not found:
# Roselline di prosciutto crudo su fichi
# Nome Piatto not found:
# Hummus
# Nome Piatto not found:
# Hummus
# Nome Piatto not found:
# Hummus
# Nome Piatto not found:
# Hummus
# Nome Piatto not found:
# Hummus
# Nome Piatto not found:
# Hummus
# Nome Piatto not found:
# Hummus
# Nome Piatto not found:
# Hummus
# Nome Piatto not found:
# Hummus
# Nome Piatto not found:
# Hummus
# Nome Piatto not found:
# Caprese sfiziosa con salsa all'origano
# Nome Piatto not found:
# Caprese sfiziosa con salsa all'origano
# Nome Piatto not found:
# Caprese sfiziosa con salsa all'origano
# Nome Piatto not found:
# Caprese sfiziosa con salsa all'origano
# Nome Piatto not found:
# Caprese sfiziosa con salsa all'origano
# Nome Piatto not found:
# Caprese sfiziosa con salsa all'origano
# Nome Piatto not found:
# Suppl� al telefono
# Nome Piatto not found:
# Suppl� al telefono
# Nome Piatto not found:
# Suppl� al telefono
# Nome Piatto not found:
# Suppl� al telefono
# Nome Piatto not found:
# Suppl� al telefono
# Nome Piatto not found:
# Suppl� al telefono
# Nome Piatto not found:
# Suppl� al telefono
# Nome Piatto not found:
# Suppl� al telefono
# Nome Piatto not found:
# Suppl� al telefono
# Nome Piatto not found:
# Suppl� al telefono
# Nome Piatto not found:
# Suppl� al telefono
# Nome Piatto not found:
# Suppl� al telefono
# Nome Piatto not found:
# Suppl� al telefono
# Nome Piatto not found:
# Suppl� al telefono
# Nome Piatto not found:
# Suppl� al telefono
# Nome Piatto not found:
# Suppl� al telefono
# Nome Piatto not found:
# Suppl� al telefono
# Nome Piatto not found:
# Suppl� al telefono
# Nome Piatto not found:
# Crocchette di patate al forno
# Nome Piatto not found:
# Crocchette di patate al forno
# Nome Piatto not found:
# Crocchette di patate al forno
# Nome Piatto not found:
# Crocchette di patate al forno
# Nome Piatto not found:
# Crocchette di patate al forno
# Nome Piatto not found:
# Crocchette di patate al forno
# Nome Piatto not found:
# Crocchette di patate al forno
# Nome Piatto not found:
# Crocchette di patate al forno
# Nome Piatto not found:
# Crocchette di patate al forno
# Nome Piatto not found:
# Asparagi in sfoglia con crudo
# Nome Piatto not found:
# Asparagi in sfoglia con crudo
# Nome Piatto not found:
# Asparagi in sfoglia con crudo
# Nome Piatto not found:
# Asparagi in sfoglia con crudo
# Nome Piatto not found:
# Asparagi in sfoglia con crudo
# Nome Piatto not found:
# Sbriciolata di patate
# Nome Piatto not found:
# Sbriciolata di patate
# Nome Piatto not found:
# Sbriciolata di patate
# Nome Piatto not found:
# Sbriciolata di patate
# Nome Piatto not found:
# Sbriciolata di patate
# Nome Piatto not found:
# Sbriciolata di patate
# Nome Piatto not found:
# Sbriciolata di patate
# Nome Piatto not found:
# Sbriciolata di patate
# Nome Piatto not found:
# Sbriciolata di patate
# Nome Piatto not found:
# Insalata di zucchine alla menta e basilico
# Nome Piatto not found:
# Insalata di zucchine alla menta e basilico
# Nome Piatto not found:
# Insalata di zucchine alla menta e basilico
# Nome Piatto not found:
# Insalata di zucchine alla menta e basilico
# Nome Piatto not found:
# Insalata di zucchine alla menta e basilico
# Nome Piatto not found:
# Insalata di zucchine alla menta e basilico
# Nome Piatto not found:
# Insalata di zucchine alla menta e basilico
# Nome Piatto not found:
# Insalata di zucchine alla menta e basilico
# Nome Piatto not found:
# Salsa cocktail
# Nome Piatto not found:
# Salsa cocktail
# Nome Piatto not found:
# Salsa cocktail
# Nome Piatto not found:
# Salsa cocktail
# Nome Piatto not found:
# Salsa cocktail
# Nome Piatto not found:
# Salsa cocktail
# Nome Piatto not found:
# Salsa cocktail
# Nome Piatto not found:
# Salsa cocktail
# Nome Piatto not found:
# Salsa cocktail
# Nome Piatto not found:
# Plumcake alle zucchine
# Nome Piatto not found:
# Plumcake alle zucchine
# Nome Piatto not found:
# Plumcake alle zucchine
# Nome Piatto not found:
# Plumcake alle zucchine
# Nome Piatto not found:
# Plumcake alle zucchine
# Nome Piatto not found:
# Plumcake alle zucchine
# Nome Piatto not found:
# Plumcake alle zucchine
# Nome Piatto not found:
# Plumcake alle zucchine
# Nome Piatto not found:
# Plumcake alle zucchine
# Nome Piatto not found:
# Plumcake alle zucchine
# Nome Piatto not found:
# Involtini di verza
# Nome Piatto not found:
# Involtini di verza
# Nome Piatto not found:
# Involtini di verza
# Nome Piatto not found:
# Involtini di verza
# Nome Piatto not found:
# Involtini di verza
# Nome Piatto not found:
# Involtini di verza
# Nome Piatto not found:
# Involtini di verza
# Nome Piatto not found:
# Involtini di verza
# Nome Piatto not found:
# Involtini di verza
# Nome Piatto not found:
# Involtini di verza
# Nome Piatto not found:
# Involtini di verza
# Nome Piatto not found:
# Involtini di verza
# Nome Piatto not found:
# Involtini di verza
# Nome Piatto not found:
# Involtini di verza
# Nome Piatto not found:
# Tomino in crosta di sfoglia
# Nome Piatto not found:
# Tomino in crosta di sfoglia
# Nome Piatto not found:
# Tomino in crosta di sfoglia
# Nome Piatto not found:
# Tomino in crosta di sfoglia
# Nome Piatto not found:
# Tomino in crosta di sfoglia
# Nome Piatto not found:
# Tomino in crosta di sfoglia
# Nome Piatto not found:
# Tomino in crosta di sfoglia
# Nome Piatto not found:
# Gamberi in crosta
# Nome Piatto not found:
# Gamberi in crosta
# Nome Piatto not found:
# Gamberi in crosta
# Nome Piatto not found:
# Gamberi in crosta
# Nome Piatto not found:
# Gamberi in crosta
# Nome Piatto not found:
# Gamberi in crosta
# Nome Piatto not found:
# Gamberi in crosta
# Nome Piatto not found:
# Gamberi in crosta
# Nome Piatto not found:
# Gamberi in crosta
# Nome Piatto not found:
# Gamberi in crosta
# Nome Piatto not found:
# Gamberi in crosta
# Nome Piatto not found:
# Gamberi in crosta
# Nome Piatto not found:
# Gamberi in crosta
# Nome Piatto not found:
# Gamberi in crosta
# Nome Piatto not found:
# Gamberi in crosta
# Nome Piatto not found:
# Tortino di patate in padella
# Nome Piatto not found:
# Tortino di patate in padella
# Nome Piatto not found:
# Tortino di patate in padella
# Nome Piatto not found:
# Tortino di patate in padella
# Nome Piatto not found:
# Tortino di patate in padella
# Nome Piatto not found:
# Insalata allo yogurt con salmone e gamberetti
# Nome Piatto not found:
# Insalata allo yogurt con salmone e gamberetti
# Nome Piatto not found:
# Insalata allo yogurt con salmone e gamberetti
# Nome Piatto not found:
# Insalata allo yogurt con salmone e gamberetti
# Nome Piatto not found:
# Insalata allo yogurt con salmone e gamberetti
# Nome Piatto not found:
# Insalata allo yogurt con salmone e gamberetti
# Nome Piatto not found:
# Insalata allo yogurt con salmone e gamberetti
# Nome Piatto not found:
# Insalata allo yogurt con salmone e gamberetti
# Nome Piatto not found:
# Insalata allo yogurt con salmone e gamberetti
# Nome Piatto not found:
# Insalata allo yogurt con salmone e gamberetti
# Nome Piatto not found:
# Pesce finto
# Nome Piatto not found:
# Pesce finto
# Nome Piatto not found:
# Pesce finto
# Nome Piatto not found:
# Pesce finto
# Nome Piatto not found:
# Pesce finto
# Nome Piatto not found:
# Pesce finto
# Nome Piatto not found:
# Pesce finto
# Nome Piatto not found:
# Pesce finto
# Nome Piatto not found:
# Pesce finto
# Nome Piatto not found:
# Pesce finto
# Nome Piatto not found:
# Pesce finto
# Nome Piatto not found:
# Pesce finto
# Nome Piatto not found:
# Pesce finto
# Nome Piatto not found:
# Pesce finto
# Nome Piatto not found:
# Olive all' ascolana
# Nome Piatto not found:
# Olive all' ascolana
# Nome Piatto not found:
# Olive all' ascolana
# Nome Piatto not found:
# Olive all' ascolana
# Nome Piatto not found:
# Olive all' ascolana
# Nome Piatto not found:
# Olive all' ascolana
# Nome Piatto not found:
# Olive all' ascolana
# Nome Piatto not found:
# Olive all' ascolana
# Nome Piatto not found:
# Olive all' ascolana
# Nome Piatto not found:
# Olive all' ascolana
# Nome Piatto not found:
# Olive all' ascolana
# Nome Piatto not found:
# Olive all' ascolana
# Nome Piatto not found:
# Olive all' ascolana
# Nome Piatto not found:
# Olive all' ascolana
# Nome Piatto not found:
# Olive all' ascolana
# Nome Piatto not found:
# Olive all' ascolana
# Nome Piatto not found:
# Olive all' ascolana
# Nome Piatto not found:
# Olive all' ascolana
# Nome Piatto not found:
# Olive all' ascolana
# Nome Piatto not found:
# Friselle con pomodoro e alici
# Nome Piatto not found:
# Friselle con pomodoro e alici
# Nome Piatto not found:
# Friselle con pomodoro e alici
# Nome Piatto not found:
# Friselle con pomodoro e alici
# Nome Piatto not found:
# Friselle con pomodoro e alici
# Nome Piatto not found:
# Friselle con pomodoro e alici
# Nome Piatto not found:
# Friselle con pomodoro e alici
# Nome Piatto not found:
# Friselle con pomodoro e alici
# Nome Piatto not found:
# Friselle con pomodoro e alici
# Nome Piatto not found:
# Friselle con pomodoro e alici
# Nome Piatto not found:
# Frollini al Parmigiano
# Nome Piatto not found:
# Frollini al Parmigiano
# Nome Piatto not found:
# Frollini al Parmigiano
# Nome Piatto not found:
# Frollini al Parmigiano
# Nome Piatto not found:
# Frollini al Parmigiano
# Nome Piatto not found:
# Frollini al Parmigiano
# Nome Piatto not found:
# Frollini al Parmigiano
# Nome Piatto not found:
# Frollini al Parmigiano
# Nome Piatto not found:
# Frollini al Parmigiano
# Nome Piatto not found:
# Frollini al Parmigiano
# Nome Piatto not found:
# Pizzette di zucchine
# Nome Piatto not found:
# Pizzette di zucchine
# Nome Piatto not found:
# Pizzette di zucchine
# Nome Piatto not found:
# Pizzette di zucchine
# Nome Piatto not found:
# Pizzette di zucchine
# Nome Piatto not found:
# Pizzette di zucchine
# Nome Piatto not found:
# Pizzette di zucchine
# Nome Piatto not found:
# Polpette di lenticchie
# Nome Piatto not found:
# Polpette di lenticchie
# Nome Piatto not found:
# Polpette di lenticchie
# Nome Piatto not found:
# Polpette di lenticchie
# Nome Piatto not found:
# Polpette di lenticchie
# Nome Piatto not found:
# Polpette di lenticchie
# Nome Piatto not found:
# Polpette di lenticchie
# Nome Piatto not found:
# Polpette di lenticchie
# Nome Piatto not found:
# Polpette di lenticchie
# Nome Piatto not found:
# Frittatine di pasta napoletane
# Nome Piatto not found:
# Frittatine di pasta napoletane
# Nome Piatto not found:
# Frittatine di pasta napoletane
# Nome Piatto not found:
# Frittatine di pasta napoletane
# Nome Piatto not found:
# Frittatine di pasta napoletane
# Nome Piatto not found:
# Frittatine di pasta napoletane
# Nome Piatto not found:
# Frittatine di pasta napoletane
# Nome Piatto not found:
# Frittatine di pasta napoletane
# Nome Piatto not found:
# Frittatine di pasta napoletane
# Nome Piatto not found:
# Frittatine di pasta napoletane
# Nome Piatto not found:
# Frittatine di pasta napoletane
# Nome Piatto not found:
# Frittatine di pasta napoletane
# Nome Piatto not found:
# Frittatine di pasta napoletane
# Nome Piatto not found:
# Chips di patate
# Nome Piatto not found:
# Chips di patate
# Nome Piatto not found:
# Chips di patate
# Nome Piatto not found:
# Panelle
# Nome Piatto not found:
# Panelle
# Nome Piatto not found:
# Panelle
# Nome Piatto not found:
# Panelle
# Nome Piatto not found:
# Panelle
# Nome Piatto not found:
# Panelle
# Nome Piatto not found:
# Melanzane alla sarda
# Nome Piatto not found:
# Melanzane alla sarda
# Nome Piatto not found:
# Melanzane alla sarda
# Nome Piatto not found:
# Melanzane alla sarda
# Nome Piatto not found:
# Melanzane alla sarda
# Nome Piatto not found:
# Melanzane alla sarda
# Nome Piatto not found:
# Melanzane alla sarda
# Nome Piatto not found:
# Teste di champignon ripieni
# Nome Piatto not found:
# Teste di champignon ripieni
# Nome Piatto not found:
# Teste di champignon ripieni
# Nome Piatto not found:
# Teste di champignon ripieni
# Nome Piatto not found:
# Teste di champignon ripieni
# Nome Piatto not found:
# Teste di champignon ripieni
# Nome Piatto not found:
# Teste di champignon ripieni
# Nome Piatto not found:
# Teste di champignon ripieni
# Nome Piatto not found:
# Teste di champignon ripieni
# Nome Piatto not found:
# Saut� di cozze e vongole
# Nome Piatto not found:
# Saut� di cozze e vongole
# Nome Piatto not found:
# Saut� di cozze e vongole
# Nome Piatto not found:
# Saut� di cozze e vongole
# Nome Piatto not found:
# Saut� di cozze e vongole
# Nome Piatto not found:
# Saut� di cozze e vongole
# Nome Piatto not found:
# Polpette di tonno e patate
# Nome Piatto not found:
# Polpette di tonno e patate
# Nome Piatto not found:
# Polpette di tonno e patate
# Nome Piatto not found:
# Polpette di tonno e patate
# Nome Piatto not found:
# Polpette di tonno e patate
# Nome Piatto not found:
# Polpette di tonno e patate
# Nome Piatto not found:
# Polpette di tonno e patate
# Nome Piatto not found:
# Polpette di tonno e patate
# Nome Piatto not found:
# Polpette di tonno e patate
# Nome Piatto not found:
# Polpette di tonno e patate
# Nome Piatto not found:
# Spiedini di gamberi
# Nome Piatto not found:
# Spiedini di gamberi
# Nome Piatto not found:
# Spiedini di gamberi
# Nome Piatto not found:
# Spiedini di gamberi
# Nome Piatto not found:
# Spiedini di gamberi
# Nome Piatto not found:
# Spiedini di gamberi
# Nome Piatto not found:
# Spiedini di gamberi
# Nome Piatto not found:
# Peperoni ripieni vegetariani
# Nome Piatto not found:
# Peperoni ripieni vegetariani
# Nome Piatto not found:
# Peperoni ripieni vegetariani
# Nome Piatto not found:
# Peperoni ripieni vegetariani
# Nome Piatto not found:
# Peperoni ripieni vegetariani
# Nome Piatto not found:
# Peperoni ripieni vegetariani
# Nome Piatto not found:
# Peperoni ripieni vegetariani
# Nome Piatto not found:
# Peperoni ripieni vegetariani
# Nome Piatto not found:
# Peperoni ripieni vegetariani
# Nome Piatto not found:
# Tartare di tonno
# Nome Piatto not found:
# Tartare di tonno
# Nome Piatto not found:
# Tartare di tonno
# Nome Piatto not found:
# Tartare di tonno
# Nome Piatto not found:
# Tartare di tonno
# Nome Piatto not found:
# Tartare di tonno
# Nome Piatto not found:
# Tartare di tonno
# Nome Piatto not found:
# Avocado toast
# Nome Piatto not found:
# Avocado toast
# Nome Piatto not found:
# Avocado toast
# Nome Piatto not found:
# Avocado toast
# Nome Piatto not found:
# Avocado toast
# Nome Piatto not found:
# Avocado toast
# Nome Piatto not found:
# Avocado toast
# Nome Piatto not found:
# Avocado toast
# Nome Piatto not found:
# Avocado toast
# Nome Piatto not found:
# Avocado toast
# Nome Piatto not found:
# Avocado toast
# Nome Piatto not found:
# Avocado toast
# Nome Piatto not found:
# Avocado toast
# Nome Piatto not found:
# Avocado toast
# Nome Piatto not found:
# Avocado toast
# Nome Piatto not found:
# Avocado toast
# Nome Piatto not found:
# Avocado toast
# Nome Piatto not found:
# Avocado toast
# Nome Piatto not found:
# Avocado toast
# Nome Piatto not found:
# Avocado toast
# Nome Piatto not found:
# Polpette di zucca
# Nome Piatto not found:
# Polpette di zucca
# Nome Piatto not found:
# Polpette di zucca
# Nome Piatto not found:
# Polpette di zucca
# Nome Piatto not found:
# Polpette di zucca
# Nome Piatto not found:
# Polpette di zucca
# Nome Piatto not found:
# Polpette di zucca
# Nome Piatto not found:
# Polpette di zucca
# Nome Piatto not found:
# Polpette di zucca
# Nome Piatto not found:
# Polpette di zucca
# Nome Piatto not found:
# Polpette di zucca
# Nome Piatto not found:
# Pizza muffin
# Nome Piatto not found:
# Pizza muffin
# Nome Piatto not found:
# Pizza muffin
# Nome Piatto not found:
# Pizza muffin
# Nome Piatto not found:
# Pizza muffin
# Nome Piatto not found:
# Pizza muffin
# Nome Piatto not found:
# Pizza muffin
# Nome Piatto not found:
# Pizza muffin
# Nome Piatto not found:
# Mozzarella ripiena
# Nome Piatto not found:
# Mozzarella ripiena
# Nome Piatto not found:
# Mozzarella ripiena
# Nome Piatto not found:
# Mozzarella ripiena
# Nome Piatto not found:
# Mozzarella ripiena
# Nome Piatto not found:
# Mozzarella ripiena
# Nome Piatto not found:
# Friggitelli ripieni vegetariani
# Nome Piatto not found:
# Friggitelli ripieni vegetariani
# Nome Piatto not found:
# Friggitelli ripieni vegetariani
# Nome Piatto not found:
# Friggitelli ripieni vegetariani
# Nome Piatto not found:
# Friggitelli ripieni vegetariani
# Nome Piatto not found:
# Friggitelli ripieni vegetariani
# Nome Piatto not found:
# Friggitelli ripieni vegetariani
# Nome Piatto not found:
# Friggitelli ripieni vegetariani
# Nome Piatto not found:
# Rotolini di zucchina in sfoglia
# Nome Piatto not found:
# Rotolini di zucchina in sfoglia
# Nome Piatto not found:
# Rotolini di zucchina in sfoglia
# Nome Piatto not found:
# Rotolini di zucchina in sfoglia
# Nome Piatto not found:
# Rotolini di zucchina in sfoglia
# Nome Piatto not found:
# Rotolini di zucchina in sfoglia
# Nome Piatto not found:
# Fagottini di porri. salmone e robiola
# Nome Piatto not found:
# Fagottini di porri. salmone e robiola
# Nome Piatto not found:
# Fagottini di porri. salmone e robiola
# Nome Piatto not found:
# Fagottini di porri. salmone e robiola
# Nome Piatto not found:
# Fagottini di porri. salmone e robiola
# Nome Piatto not found:
# Fagottini di porri. salmone e robiola
# Nome Piatto not found:
# Fagottini di porri. salmone e robiola
# Nome Piatto not found:
# Fagottini di porri. salmone e robiola
# Nome Piatto not found:
# Fagottini di porri. salmone e robiola
# Nome Piatto not found:
# Fagottini di porri. salmone e robiola
# Nome Piatto not found:
# Fagottini di porri. salmone e robiola
# Nome Piatto not found:
# Fagottini di porri. salmone e robiola
# Nome Piatto not found:
# Fagottini di porri. salmone e robiola
# Nome Piatto not found:
# Fagottini di porri. salmone e robiola
# Nome Piatto not found:
# Fagottini di porri. salmone e robiola
# Nome Piatto not found:
# Anelli di cipolla in pastella
# Nome Piatto not found:
# Anelli di cipolla in pastella
# Nome Piatto not found:
# Anelli di cipolla in pastella
# Nome Piatto not found:
# Anelli di cipolla in pastella
# Nome Piatto not found:
# Anelli di cipolla in pastella
# Nome Piatto not found:
# Anelli di cipolla in pastella
# Nome Piatto not found:
# Anelli di cipolla in pastella
# Nome Piatto not found:
# Anelli di cipolla in pastella
# Nome Piatto not found:
# Baccal� mantecato alla veneziana
# Nome Piatto not found:
# Baccal� mantecato alla veneziana
# Nome Piatto not found:
# Baccal� mantecato alla veneziana
# Nome Piatto not found:
# Baccal� mantecato alla veneziana
# Nome Piatto not found:
# Baccal� mantecato alla veneziana
# Nome Piatto not found:
# Baccal� mantecato alla veneziana
# Nome Piatto not found:
# Baccal� mantecato alla veneziana
# Nome Piatto not found:
# Baccal� mantecato alla veneziana
# Nome Piatto not found:
# Baccal� mantecato alla veneziana
# Nome Piatto not found:
# Churros
# Nome Piatto not found:
# Churros
# Nome Piatto not found:
# Churros
# Nome Piatto not found:
# Churros
# Nome Piatto not found:
# Churros
# Nome Piatto not found:
# Churros
# Nome Piatto not found:
# Churros
# Nome Piatto not found:
# Churros
# Nome Piatto not found:
# Vitello tonnato alla maniera antica
# Nome Piatto not found:
# Vitello tonnato alla maniera antica
# Nome Piatto not found:
# Vitello tonnato alla maniera antica
# Nome Piatto not found:
# Vitello tonnato alla maniera antica
# Nome Piatto not found:
# Vitello tonnato alla maniera antica
# Nome Piatto not found:
# Vitello tonnato alla maniera antica
# Nome Piatto not found:
# Vitello tonnato alla maniera antica
# Nome Piatto not found:
# Vitello tonnato alla maniera antica
# Nome Piatto not found:
# Vitello tonnato alla maniera antica
# Nome Piatto not found:
# Vitello tonnato alla maniera antica
# Nome Piatto not found:
# Vitello tonnato alla maniera antica
# Nome Piatto not found:
# Vitello tonnato alla maniera antica
# Nome Piatto not found:
# Vitello tonnato alla maniera antica
# Nome Piatto not found:
# Polpette di patate al forno
# Nome Piatto not found:
# Polpette di patate al forno
# Nome Piatto not found:
# Polpette di patate al forno
# Nome Piatto not found:
# Polpette di patate al forno
# Nome Piatto not found:
# Polpette di patate al forno
# Nome Piatto not found:
# Polpette di patate al forno
# Nome Piatto not found:
# Polpette di patate al forno
# Nome Piatto not found:
# Polpette di patate al forno
# Nome Piatto not found:
# Polpette di patate al forno
# Nome Piatto not found:
# Polpette di patate al forno
# Nome Piatto not found:
# Polpette di patate al forno
# Nome Piatto not found:
# Polpette di patate al forno
# Nome Piatto not found:
# Polpette di patate al forno
# Nome Piatto not found:
# Cotolette di melanzane
# Nome Piatto not found:
# Cotolette di melanzane
# Nome Piatto not found:
# Cotolette di melanzane
# Nome Piatto not found:
# Cotolette di melanzane
# Nome Piatto not found:
# Cotolette di melanzane
# Nome Piatto not found:
# Cotolette di melanzane
# Nome Piatto not found:
# Cotolette di melanzane
# Nome Piatto not found:
# Cotolette di melanzane
# Nome Piatto not found:
# Cotolette di melanzane
# Nome Piatto not found:
# Cotolette di melanzane
# Nome Piatto not found:
# Cotolette di melanzane
# Nome Piatto not found:
# Cotolette di melanzane
# Nome Piatto not found:
# Cotolette di melanzane
# Nome Piatto not found:
# Cotolette di melanzane
# Nome Piatto not found:
# Cotolette di melanzane
# Nome Piatto not found:
# Cotolette di melanzane
# Nome Piatto not found:
# Cotolette di melanzane
# Nome Piatto not found:
# Frittata di asparagi
# Nome Piatto not found:
# Frittata di asparagi
# Nome Piatto not found:
# Frittata di asparagi
# Nome Piatto not found:
# Frittata di asparagi
# Nome Piatto not found:
# Frittata di asparagi
# Nome Piatto not found:
# Frittata di asparagi
# Nome Piatto not found:
# Frittata di asparagi
# Nome Piatto not found:
# Frittata di asparagi
# Nome Piatto not found:
# Frittata di asparagi
# Nome Piatto not found:
# Frittata di asparagi
# Nome Piatto not found:
# Pasta bris�
# Nome Piatto not found:
# Pasta bris�
# Nome Piatto not found:
# Pasta bris�
# Nome Piatto not found:
# Pasta bris�
# Nome Piatto not found:
# Mini cheesecake al salmone
# Nome Piatto not found:
# Mini cheesecake al salmone
# Nome Piatto not found:
# Mini cheesecake al salmone
# Nome Piatto not found:
# Mini cheesecake al salmone
# Nome Piatto not found:
# Mini cheesecake al salmone
# Nome Piatto not found:
# Mini cheesecake al salmone
# Nome Piatto not found:
# Mini cheesecake al salmone
# Nome Piatto not found:
# Mini cheesecake al salmone
# Nome Piatto not found:
# Mini cheesecake al salmone
# Nome Piatto not found:
# Sformato di zucchine
# Nome Piatto not found:
# Sformato di zucchine
# Nome Piatto not found:
# Sformato di zucchine
# Nome Piatto not found:
# Sformato di zucchine
# Nome Piatto not found:
# Sformato di zucchine
# Nome Piatto not found:
# Sformato di zucchine
# Nome Piatto not found:
# Sformato di zucchine
# Nome Piatto not found:
# Sformato di zucchine
# Nome Piatto not found:
# Sformato di zucchine
# Nome Piatto not found:
# Sformato di zucchine
# Nome Piatto not found:
# Sformato di zucchine
# Nome Piatto not found:
# Sformato di zucchine
# Nome Piatto not found:
# Sformato di zucchine
# Nome Piatto not found:
# Sformato di zucchine
# Nome Piatto not found:
# Sformato di zucchine
# Nome Piatto not found:
# Sformato di zucchine
# Nome Piatto not found:
# Frittatine nella pancetta
# Nome Piatto not found:
# Frittatine nella pancetta
# Nome Piatto not found:
# Frittatine nella pancetta
# Nome Piatto not found:
# Frittatine nella pancetta
# Nome Piatto not found:
# Frittatine nella pancetta
# Nome Piatto not found:
# Frittatine nella pancetta
# Nome Piatto not found:
# Frittatine nella pancetta
# Nome Piatto not found:
# Carpaccio di polpo
# Nome Piatto not found:
# Carpaccio di polpo
# Nome Piatto not found:
# Carpaccio di polpo
# Nome Piatto not found:
# Carpaccio di polpo
# Nome Piatto not found:
# Carpaccio di polpo
# Nome Piatto not found:
# Carpaccio di polpo
# Nome Piatto not found:
# Carpaccio di polpo
# Nome Piatto not found:
# Carpaccio di polpo
# Nome Piatto not found:
# Carpaccio di polpo
# Nome Piatto not found:
# Carpaccio di polpo
# Nome Piatto not found:
# Carpaccio di polpo
# Nome Piatto not found:
# Carpaccio di polpo
# Nome Piatto not found:
# Mozzarella fritta
# Nome Piatto not found:
# Mozzarella fritta
# Nome Piatto not found:
# Mozzarella fritta
# Nome Piatto not found:
# Mozzarella fritta
# Nome Piatto not found:
# Mozzarella fritta
# Nome Piatto not found:
# Mozzarella fritta
# Nome Piatto not found:
# Mozzarella fritta
# Nome Piatto not found:
# Mozzarella fritta
# Nome Piatto not found:
# Strudel con ricotta e spinaci
# Nome Piatto not found:
# Strudel con ricotta e spinaci
# Nome Piatto not found:
# Strudel con ricotta e spinaci
# Nome Piatto not found:
# Strudel con ricotta e spinaci
# Nome Piatto not found:
# Strudel con ricotta e spinaci
# Nome Piatto not found:
# Strudel con ricotta e spinaci
# Nome Piatto not found:
# Strudel con ricotta e spinaci
# Nome Piatto not found:
# Strudel con ricotta e spinaci
# Nome Piatto not found:
# Strudel con ricotta e spinaci
# Nome Piatto not found:
# Strudel con ricotta e spinaci
# Nome Piatto not found:
# Strudel con ricotta e spinaci
# Nome Piatto not found:
# Strudel con ricotta e spinaci
# Nome Piatto not found:
# Croque monsieur
# Nome Piatto not found:
# Croque monsieur
# Nome Piatto not found:
# Croque monsieur
# Nome Piatto not found:
# Croque monsieur
# Nome Piatto not found:
# Croque monsieur
# Nome Piatto not found:
# Croque monsieur
# Nome Piatto not found:
# Croque monsieur
# Nome Piatto not found:
# Croque monsieur
# Nome Piatto not found:
# Croque monsieur
# Nome Piatto not found:
# Gazpacho andaluso
# Nome Piatto not found:
# Gazpacho andaluso
# Nome Piatto not found:
# Gazpacho andaluso
# Nome Piatto not found:
# Gazpacho andaluso
# Nome Piatto not found:
# Gazpacho andaluso
# Nome Piatto not found:
# Gazpacho andaluso
# Nome Piatto not found:
# Gazpacho andaluso
# Nome Piatto not found:
# Gazpacho andaluso
# Nome Piatto not found:
# Gazpacho andaluso
# Nome Piatto not found:
# Gazpacho andaluso
# Nome Piatto not found:
# Gazpacho andaluso
# Nome Piatto not found:
# Gazpacho andaluso
# Nome Piatto not found:
# Gazpacho andaluso
# Nome Piatto not found:
# Gazpacho andaluso
# Nome Piatto not found:
# Gazpacho andaluso
# Nome Piatto not found:
# Gazpacho andaluso
# Nome Piatto not found:
# Gazpacho andaluso
# Nome Piatto not found:
# Peperoni con la mollica
# Nome Piatto not found:
# Peperoni con la mollica
# Nome Piatto not found:
# Peperoni con la mollica
# Nome Piatto not found:
# Peperoni con la mollica
# Nome Piatto not found:
# Peperoni con la mollica
# Nome Piatto not found:
# Peperoni con la mollica
# Nome Piatto not found:
# Peperoni con la mollica
# Nome Piatto not found:
# Peperoni con la mollica
# Nome Piatto not found:
# Torta di zucchine e i suoi fiori
# Nome Piatto not found:
# Torta di zucchine e i suoi fiori
# Nome Piatto not found:
# Torta di zucchine e i suoi fiori
# Nome Piatto not found:
# Torta di zucchine e i suoi fiori
# Nome Piatto not found:
# Torta di zucchine e i suoi fiori
# Nome Piatto not found:
# Torta di zucchine e i suoi fiori
# Nome Piatto not found:
# Torta di zucchine e i suoi fiori
# Nome Piatto not found:
# Torta di zucchine e i suoi fiori
# Nome Piatto not found:
# Torta di zucchine e i suoi fiori
# Nome Piatto not found:
# Torta di zucchine e i suoi fiori
# Nome Piatto not found:
# Torta di zucchine e i suoi fiori
# Nome Piatto not found:
# Torta salata agli spinaci
# Nome Piatto not found:
# Torta salata agli spinaci
# Nome Piatto not found:
# Torta salata agli spinaci
# Nome Piatto not found:
# Torta salata agli spinaci
# Nome Piatto not found:
# Torta salata agli spinaci
# Nome Piatto not found:
# Torta salata agli spinaci
# Nome Piatto not found:
# Torta salata agli spinaci
# Nome Piatto not found:
# Torta salata agli spinaci
# Nome Piatto not found:
# Torta salata agli spinaci
# Nome Piatto not found:
# Torta salata agli spinaci
# Nome Piatto not found:
# Torta salata agli spinaci
# Nome Piatto not found:
# Torta salata agli spinaci
# Nome Piatto not found:
# Torta salata agli spinaci
# Nome Piatto not found:
# Alici marinate
# Nome Piatto not found:
# Alici marinate
# Nome Piatto not found:
# Alici marinate
# Nome Piatto not found:
# Alici marinate
# Nome Piatto not found:
# Alici marinate
# Nome Piatto not found:
# Alici marinate
# Nome Piatto not found:
# Alici marinate
# Nome Piatto not found:
# Alici marinate
# Nome Piatto not found:
# Cozze alla marinara
# Nome Piatto not found:
# Cozze alla marinara
# Nome Piatto not found:
# Cozze alla marinara
# Nome Piatto not found:
# Cozze alla marinara
# Nome Piatto not found:
# Babaganoush
# Nome Piatto not found:
# Babaganoush
# Nome Piatto not found:
# Babaganoush
# Nome Piatto not found:
# Babaganoush
# Nome Piatto not found:
# Babaganoush
# Nome Piatto not found:
# Babaganoush
# Nome Piatto not found:
# Babaganoush
# Nome Piatto not found:
# Babaganoush
# Nome Piatto not found:
# Frittata
# Nome Piatto not found:
# Frittata
# Nome Piatto not found:
# Frittata
# Nome Piatto not found:
# Frittata
# Nome Piatto not found:
# Frittata
# Nome Piatto not found:
# Frittata
# Nome Piatto not found:
# Pizza di scarola
# Nome Piatto not found:
# Pizza di scarola
# Nome Piatto not found:
# Pizza di scarola
# Nome Piatto not found:
# Pizza di scarola
# Nome Piatto not found:
# Pizza di scarola
# Nome Piatto not found:
# Pizza di scarola
# Nome Piatto not found:
# Pizza di scarola
# Nome Piatto not found:
# Pizza di scarola
# Nome Piatto not found:
# Pizza di scarola
# Nome Piatto not found:
# Pizza di scarola
# Nome Piatto not found:
# Pizzelle fritte
# Nome Piatto not found:
# Pizzelle fritte
# Nome Piatto not found:
# Pizzelle fritte
# Nome Piatto not found:
# Pizzelle fritte
# Nome Piatto not found:
# Pizzelle fritte
# Nome Piatto not found:
# Pizzelle fritte
# Nome Piatto not found:
# Pizzelle fritte
# Nome Piatto not found:
# Pizzelle fritte
# Nome Piatto not found:
# Pizzelle fritte
# Nome Piatto not found:
# Pizzelle fritte
# Nome Piatto not found:
# Pizzelle fritte
# Nome Piatto not found:
# Pizzelle fritte
# Nome Piatto not found:
# Grissini
# Nome Piatto not found:
# Grissini
# Nome Piatto not found:
# Grissini
# Nome Piatto not found:
# Grissini
# Nome Piatto not found:
# Grissini
# Nome Piatto not found:
# Grissini
# Nome Piatto not found:
# Grissini
# Nome Piatto not found:
# Grissini
# Nome Piatto not found:
# Panzanella
# Nome Piatto not found:
# Panzanella
# Nome Piatto not found:
# Panzanella
# Nome Piatto not found:
# Panzanella
# Nome Piatto not found:
# Panzanella
# Nome Piatto not found:
# Panzanella
# Nome Piatto not found:
# Panzanella
# Nome Piatto not found:
# Panzanella
# Nome Piatto not found:
# Panzanella
# Nome Piatto not found:
# Panzanella
# Nome Piatto not found:
# Uova in camicia
# Nome Piatto not found:
# Uova in camicia
# Nome Piatto not found:
# Uova in camicia
# Nome Piatto not found:
# Uova in camicia
# Nome Piatto not found:
# Uova in camicia
# Nome Piatto not found:
# Frittelle di sciurilli
# Nome Piatto not found:
# Frittelle di sciurilli
# Nome Piatto not found:
# Frittelle di sciurilli
# Nome Piatto not found:
# Frittelle di sciurilli
# Nome Piatto not found:
# Frittelle di sciurilli
# Nome Piatto not found:
# Frittelle di sciurilli
# Nome Piatto not found:
# Frittelle di sciurilli
# Nome Piatto not found:
# Frittelle di sciurilli
# Nome Piatto not found:
# Torta di patate e prosciutto
# Nome Piatto not found:
# Torta di patate e prosciutto
# Nome Piatto not found:
# Torta di patate e prosciutto
# Nome Piatto not found:
# Torta di patate e prosciutto
# Nome Piatto not found:
# Torta di patate e prosciutto
# Nome Piatto not found:
# Torta di patate e prosciutto
# Nome Piatto not found:
# Torta di patate e prosciutto
# Nome Piatto not found:
# Torta di patate e prosciutto
# Nome Piatto not found:
# Torta di patate e prosciutto
# Nome Piatto not found:
# Torta di patate e prosciutto
# Nome Piatto not found:
# Torta di patate e prosciutto
# Nome Piatto not found:
# Fiori di zucca ripieni di speck e mozzarella
# Nome Piatto not found:
# Fiori di zucca ripieni di speck e mozzarella
# Nome Piatto not found:
# Fiori di zucca ripieni di speck e mozzarella
# Nome Piatto not found:
# Fiori di zucca ripieni di speck e mozzarella
# Nome Piatto not found:
# Fiori di zucca ripieni di speck e mozzarella
# Nome Piatto not found:
# Fiori di zucca ripieni di speck e mozzarella
# Nome Piatto not found:
# Fiori di zucca ripieni di speck e mozzarella
# Nome Piatto not found:
# Fiori di zucca ripieni di speck e mozzarella
# Nome Piatto not found:
# Fiori di zucca ripieni di speck e mozzarella
# Nome Piatto not found:
# Fiori di zucca ripieni di speck e mozzarella
# Nome Piatto not found:
# Fiori di zucca ripieni di speck e mozzarella
# Nome Piatto not found:
# Fiori di zucca ripieni di speck e mozzarella
# Nome Piatto not found:
# Polpette di ceci
# Nome Piatto not found:
# Polpette di ceci
# Nome Piatto not found:
# Polpette di ceci
# Nome Piatto not found:
# Polpette di ceci
# Nome Piatto not found:
# Polpette di ceci
# Nome Piatto not found:
# Polpette di ceci
# Nome Piatto not found:
# Polpette di ceci
# Nome Piatto not found:
# Polpette di ceci
# Nome Piatto not found:
# Polpette di ceci
# Nome Piatto not found:
# Polpette di ceci
# Nome Piatto not found:
# Polpette di ceci
# Nome Piatto not found:
# Polpette di ceci
# Nome Piatto not found:
# Polpette di ceci
# Nome Piatto not found:
# Polpette di ceci
# Nome Piatto not found:
# Polpette di ceci
# Nome Piatto not found:
# Tramezzini
# Nome Piatto not found:
# Tramezzini
# Nome Piatto not found:
# Tramezzini
# Nome Piatto not found:
# Tramezzini
# Nome Piatto not found:
# Tramezzini
# Nome Piatto not found:
# Tramezzini
# Nome Piatto not found:
# Tramezzini
# Nome Piatto not found:
# Tramezzini
# Nome Piatto not found:
# Tramezzini
# Nome Piatto not found:
# Tramezzini
# Nome Piatto not found:
# Tramezzini
# Nome Piatto not found:
# Tramezzini
# Nome Piatto not found:
# Tramezzini
# Nome Piatto not found:
# Tramezzini
# Nome Piatto not found:
# Tramezzini
# Nome Piatto not found:
# Tramezzini
# Nome Piatto not found:
# Tramezzini
# Nome Piatto not found:
# Tramezzini
# Nome Piatto not found:
# Tramezzini
# Nome Piatto not found:
# Tramezzini
# Nome Piatto not found:
# Tramezzini
# Nome Piatto not found:
# Tramezzini
# Nome Piatto not found:
# Tramezzini
# Nome Piatto not found:
# Tramezzini
# Nome Piatto not found:
# Tramezzini
# Nome Piatto not found:
# Tramezzini
# Nome Piatto not found:
# Tramezzini
# Nome Piatto not found:
# Tramezzini
# Nome Piatto not found:
# Tempura
# Nome Piatto not found:
# Tempura
# Nome Piatto not found:
# Tempura
# Nome Piatto not found:
# Tempura
# Nome Piatto not found:
# Tempura
# Nome Piatto not found:
# Tempura
# Nome Piatto not found:
# Tempura
# Nome Piatto not found:
# Tempura
# Nome Piatto not found:
# Anelli di calamari al forno
# Nome Piatto not found:
# Anelli di calamari al forno
# Nome Piatto not found:
# Anelli di calamari al forno
# Nome Piatto not found:
# Anelli di calamari al forno
# Nome Piatto not found:
# Anelli di calamari al forno
# Nome Piatto not found:
# Naan
# Nome Piatto not found:
# Naan
# Nome Piatto not found:
# Naan
# Nome Piatto not found:
# Naan
# Nome Piatto not found:
# Naan
# Nome Piatto not found:
# Naan
# Nome Piatto not found:
# Polipetti Affogati
# Nome Piatto not found:
# Polipetti Affogati
# Nome Piatto not found:
# Polipetti Affogati
# Nome Piatto not found:
# Polipetti Affogati
# Nome Piatto not found:
# Polipetti Affogati
# Nome Piatto not found:
# Polipetti Affogati
# Nome Piatto not found:
# Polipetti Affogati
# Nome Piatto not found:
# Polipetti Affogati
# Nome Piatto not found:
# Polipetti Affogati
# Nome Piatto not found:
# Cocktail di gamberetti
# Nome Piatto not found:
# Cocktail di gamberetti
# Nome Piatto not found:
# Cocktail di gamberetti
# Nome Piatto not found:
# Cocktail di gamberetti
# Nome Piatto not found:
# Cocktail di gamberetti
# Nome Piatto not found:
# Cocktail di gamberetti
# Nome Piatto not found:
# Cocktail di gamberetti
# Nome Piatto not found:
# Cocktail di gamberetti
# Nome Piatto not found:
# Cocktail di gamberetti
# Nome Piatto not found:
# Cocktail di gamberetti
# Nome Piatto not found:
# Cocktail di gamberetti
# Nome Piatto not found:
# Cocktail di gamberetti
# Nome Piatto not found:
# Empanadas argentine
# Nome Piatto not found:
# Empanadas argentine
# Nome Piatto not found:
# Empanadas argentine
# Nome Piatto not found:
# Empanadas argentine
# Nome Piatto not found:
# Empanadas argentine
# Nome Piatto not found:
# Empanadas argentine
# Nome Piatto not found:
# Empanadas argentine
# Nome Piatto not found:
# Empanadas argentine
# Nome Piatto not found:
# Empanadas argentine
# Nome Piatto not found:
# Empanadas argentine
# Nome Piatto not found:
# Empanadas argentine
# Nome Piatto not found:
# Empanadas argentine
# Nome Piatto not found:
# Empanadas argentine
# Nome Piatto not found:
# Empanadas argentine
# Nome Piatto not found:
# Empanadas argentine
# Nome Piatto not found:
# Empanadas argentine
# Nome Piatto not found:
# Empanadas argentine
# Nome Piatto not found:
# Feta al forno
# Nome Piatto not found:
# Feta al forno
# Nome Piatto not found:
# Feta al forno
# Nome Piatto not found:
# Feta al forno
# Nome Piatto not found:
# Feta al forno
# Nome Piatto not found:
# Feta al forno
# Nome Piatto not found:
# Feta al forno
# Nome Piatto not found:
# Rotolo di mozzarella farcito
# Nome Piatto not found:
# Rotolo di mozzarella farcito
# Nome Piatto not found:
# Rotolo di mozzarella farcito
# Nome Piatto not found:
# Rotolo di mozzarella farcito
# Nome Piatto not found:
# Rotolo di mozzarella farcito
# Nome Piatto not found:
# Rotolo di mozzarella farcito
# Nome Piatto not found:
# Salvia fritta in pastella
# Nome Piatto not found:
# Salvia fritta in pastella
# Nome Piatto not found:
# Salvia fritta in pastella
# Nome Piatto not found:
# Salvia fritta in pastella
# Nome Piatto not found:
# Salvia fritta in pastella
# Nome Piatto not found:
# Gamberi alla catalana
# Nome Piatto not found:
# Gamberi alla catalana
# Nome Piatto not found:
# Gamberi alla catalana
# Nome Piatto not found:
# Gamberi alla catalana
# Nome Piatto not found:
# Gamberi alla catalana
# Nome Piatto not found:
# Gamberi alla catalana
# Nome Piatto not found:
# Gamberi alla catalana
# Nome Piatto not found:
# Gamberi alla catalana
# Nome Piatto not found:
# Schiacciata di zucchine
# Nome Piatto not found:
# Schiacciata di zucchine
# Nome Piatto not found:
# Schiacciata di zucchine
# Nome Piatto not found:
# Schiacciata di zucchine
# Nome Piatto not found:
# Schiacciata di zucchine
# Nome Piatto not found:
# Schiacciata di zucchine
# Nome Piatto not found:
# Schiacciata di zucchine
# Nome Piatto not found:
# Schiacciata di zucchine
# Nome Piatto not found:
# Schiacciata di zucchine
# Nome Piatto not found:
# Ravioli di carne giapponesi (Gyoza)
# Nome Piatto not found:
# Ravioli di carne giapponesi (Gyoza)
# Nome Piatto not found:
# Ravioli di carne giapponesi (Gyoza)
# Nome Piatto not found:
# Ravioli di carne giapponesi (Gyoza)
# Nome Piatto not found:
# Ravioli di carne giapponesi (Gyoza)
# Nome Piatto not found:
# Ravioli di carne giapponesi (Gyoza)
# Nome Piatto not found:
# Ravioli di carne giapponesi (Gyoza)
# Nome Piatto not found:
# Ravioli di carne giapponesi (Gyoza)
# Nome Piatto not found:
# Ravioli di carne giapponesi (Gyoza)
# Nome Piatto not found:
# Ravioli di carne giapponesi (Gyoza)
# Nome Piatto not found:
# Ravioli di carne giapponesi (Gyoza)
# Nome Piatto not found:
# Ravioli di carne giapponesi (Gyoza)
# Nome Piatto not found:
# Ravioli di carne giapponesi (Gyoza)
# Nome Piatto not found:
# Ravioli di carne giapponesi (Gyoza)
# Nome Piatto not found:
# Taralli
# Nome Piatto not found:
# Taralli
# Nome Piatto not found:
# Taralli
# Nome Piatto not found:
# Taralli
# Nome Piatto not found:
# Torta salata di verdure
# Nome Piatto not found:
# Torta salata di verdure
# Nome Piatto not found:
# Torta salata di verdure
# Nome Piatto not found:
# Torta salata di verdure
# Nome Piatto not found:
# Torta salata di verdure
# Nome Piatto not found:
# Torta salata di verdure
# Nome Piatto not found:
# Torta salata di verdure
# Nome Piatto not found:
# Torta salata di verdure
# Nome Piatto not found:
# Torta salata di verdure
# Nome Piatto not found:
# Torta salata di verdure
# Nome Piatto not found:
# Torta salata di verdure
# Nome Piatto not found:
# Torta salata di verdure
# Nome Piatto not found:
# Mozzarella in carrozza al forno
# Nome Piatto not found:
# Mozzarella in carrozza al forno
# Nome Piatto not found:
# Mozzarella in carrozza al forno
# Nome Piatto not found:
# Mozzarella in carrozza al forno
# Nome Piatto not found:
# Mozzarella in carrozza al forno
# Nome Piatto not found:
# Mozzarella in carrozza al forno
# Nome Piatto not found:
# Mozzarella in carrozza al forno
# Nome Piatto not found:
# Tartare di salmone con crema di avocado e mandorle tostate
# Nome Piatto not found:
# Tartare di salmone con crema di avocado e mandorle tostate
# Nome Piatto not found:
# Tartare di salmone con crema di avocado e mandorle tostate
# Nome Piatto not found:
# Tartare di salmone con crema di avocado e mandorle tostate
# Nome Piatto not found:
# Tartare di salmone con crema di avocado e mandorle tostate
# Nome Piatto not found:
# Tartare di salmone con crema di avocado e mandorle tostate
# Nome Piatto not found:
# Tartare di salmone con crema di avocado e mandorle tostate
# Nome Piatto not found:
# Tartare di salmone con crema di avocado e mandorle tostate
# Nome Piatto not found:
# Tartare di salmone con crema di avocado e mandorle tostate
# Nome Piatto not found:
# Tartare di salmone con crema di avocado e mandorle tostate
# Nome Piatto not found:
# Tartare di salmone con crema di avocado e mandorle tostate
# Nome Piatto not found:
# Tartare di salmone con crema di avocado e mandorle tostate
# Nome Piatto not found:
# Tartare di salmone con crema di avocado e mandorle tostate
# Nome Piatto not found:
# Tartare di salmone con crema di avocado e mandorle tostate
# Nome Piatto not found:
# Plumcake alle verdure
# Nome Piatto not found:
# Plumcake alle verdure
# Nome Piatto not found:
# Plumcake alle verdure
# Nome Piatto not found:
# Plumcake alle verdure
# Nome Piatto not found:
# Plumcake alle verdure
# Nome Piatto not found:
# Plumcake alle verdure
# Nome Piatto not found:
# Plumcake alle verdure
# Nome Piatto not found:
# Plumcake alle verdure
# Nome Piatto not found:
# Plumcake alle verdure
# Nome Piatto not found:
# Plumcake alle verdure
# Nome Piatto not found:
# Plumcake alle verdure
# Nome Piatto not found:
# Plumcake alle verdure
# Nome Piatto not found:
# Plumcake alle verdure
# Nome Piatto not found:
# Plumcake alle verdure
# Nome Piatto not found:
# Crescentine o tigelle
# Nome Piatto not found:
# Crescentine o tigelle
# Nome Piatto not found:
# Crescentine o tigelle
# Nome Piatto not found:
# Crescentine o tigelle
# Nome Piatto not found:
# Crescentine o tigelle
# Nome Piatto not found:
# Crescentine o tigelle
# Nome Piatto not found:
# Crescentine o tigelle
# Nome Piatto not found:
# Crescentine o tigelle
# Nome Piatto not found:
# Rustici leccesi
# Nome Piatto not found:
# Rustici leccesi
# Nome Piatto not found:
# Rustici leccesi
# Nome Piatto not found:
# Rustici leccesi
# Nome Piatto not found:
# Rustici leccesi
# Nome Piatto not found:
# Rustici leccesi
# Nome Piatto not found:
# Rustici leccesi
# Nome Piatto not found:
# Rustici leccesi
# Nome Piatto not found:
# Rustici leccesi
# Nome Piatto not found:
# Rustici leccesi
# Nome Piatto not found:
# Rustici leccesi
# Nome Piatto not found:
# Rustici leccesi
# Nome Piatto not found:
# Sformatini di spinaci
# Nome Piatto not found:
# Sformatini di spinaci
# Nome Piatto not found:
# Sformatini di spinaci
# Nome Piatto not found:
# Sformatini di spinaci
# Nome Piatto not found:
# Sformatini di spinaci
# Nome Piatto not found:
# Sformatini di spinaci
# Nome Piatto not found:
# Sformatini di spinaci
# Nome Piatto not found:
# Sformatini di spinaci
# Nome Piatto not found:
# Sformatini di spinaci
# Nome Piatto not found:
# Sformatini di spinaci
# Nome Piatto not found:
# Sformatini di spinaci
# Nome Piatto not found:
# Sformatini di spinaci
# Nome Piatto not found:
# Sformatini di spinaci
# Nome Piatto not found:
# Sformatini di spinaci
# Nome Piatto not found:
# Sformatini di spinaci
# Nome Piatto not found:
# Mini calzoni al forno
# Nome Piatto not found:
# Mini calzoni al forno
# Nome Piatto not found:
# Mini calzoni al forno
# Nome Piatto not found:
# Mini calzoni al forno
# Nome Piatto not found:
# Mini calzoni al forno
# Nome Piatto not found:
# Mini calzoni al forno
# Nome Piatto not found:
# Mini calzoni al forno
# Nome Piatto not found:
# Mini calzoni al forno
# Nome Piatto not found:
# Mini calzoni al forno
# Nome Piatto not found:
# Mini calzoni al forno
# Nome Piatto not found:
# Mini calzoni al forno
# Nome Piatto not found:
# ...
# Nome Piatto not found:
# Insalata greca
# Nome Piatto not found:
# Crema catalana
# Nome Piatto not found:
# Crema catalana
# Nome Piatto not found:
# Crema catalana
# Nome Piatto not found:
# Crema catalana
# Nome Piatto not found:
# Crema catalana
# Nome Piatto not found:
# Crema catalana
# Nome Piatto not found:
# Crema catalana
# Nome Piatto not found:
# Mattonella allo yogurt con frutti di bosco
# Nome Piatto not found:
# Mattonella allo yogurt con frutti di bosco
# Nome Piatto not found:
# Mattonella allo yogurt con frutti di bosco
# Nome Piatto not found:
# Mattonella allo yogurt con frutti di bosco
# Nome Piatto not found:
# Mattonella allo yogurt con frutti di bosco
# Nome Piatto not found:
# Mattonella allo yogurt con frutti di bosco
# Nome Piatto not found:
# Mattonella allo yogurt con frutti di bosco
# Nome Piatto not found:
# Mattonella allo yogurt con frutti di bosco
# Nome Piatto not found:
# Mattonella allo yogurt con frutti di bosco
# Nome Piatto not found:
# Mattonella allo yogurt con frutti di bosco
# Nome Piatto not found:
# Mattonella allo yogurt con frutti di bosco
# Nome Piatto not found:
# Mattonella allo yogurt con frutti di bosco
# Nome Piatto not found:
# Mattonella allo yogurt con frutti di bosco
# Nome Piatto not found:
# Mattonella allo yogurt con frutti di bosco
# Nome Piatto not found:
# Mattonella allo yogurt con frutti di bosco
# Nome Piatto not found:
# Mattonella allo yogurt con frutti di bosco
# Nome Piatto not found:
# Torta di yogurt al cioccolato
# Nome Piatto not found:
# Torta di yogurt al cioccolato
# Nome Piatto not found:
# Torta di yogurt al cioccolato
# Nome Piatto not found:
# Torta di yogurt al cioccolato
# Nome Piatto not found:
# Torta di yogurt al cioccolato
# Nome Piatto not found:
# Torta di yogurt al cioccolato
# Nome Piatto not found:
# Torta di yogurt al cioccolato
# Nome Piatto not found:
# Torta di yogurt al cioccolato
# Nome Piatto not found:
# Torta di yogurt al cioccolato
# Nome Piatto not found:
# Cinnamon rolls
# Nome Piatto not found:
# Cinnamon rolls
# Nome Piatto not found:
# Cinnamon rolls
# Nome Piatto not found:
# Cinnamon rolls
# Nome Piatto not found:
# Cinnamon rolls
# Nome Piatto not found:
# Cinnamon rolls
# Nome Piatto not found:
# Cinnamon rolls
# Nome Piatto not found:
# Cinnamon rolls
# Nome Piatto not found:
# Cinnamon rolls
# Nome Piatto not found:
# Cinnamon rolls
# Nome Piatto not found:
# Cinnamon rolls
# Nome Piatto not found:
# Cinnamon rolls
# Nome Piatto not found:
# Cinnamon rolls
# Nome Piatto not found:
# Quinoa con verdure
# Nome Piatto not found:
# Quinoa con verdure
# Nome Piatto not found:
# Quinoa con verdure
# Nome Piatto not found:
# Quinoa con verdure
# Nome Piatto not found:
# Quinoa con verdure
# Nome Piatto not found:
# Quinoa con verdure
# Nome Piatto not found:
# Quinoa con verdure
# Nome Piatto not found:
# Quinoa con verdure
# Nome Piatto not found:
# Quinoa con verdure
# Nome Piatto not found:
# Quinoa con verdure
# Nome Piatto not found:
# Quinoa con verdure
# Nome Piatto not found:
# Pasta biscotto
# Nome Piatto not found:
# Pasta biscotto
# Nome Piatto not found:
# Pasta biscotto
# Nome Piatto not found:
# Pasta biscotto
# Nome Piatto not found:
# Pasta biscotto
# Nome Piatto not found:
# Polpette di verdure
# Nome Piatto not found:
# Polpette di verdure
# Nome Piatto not found:
# Polpette di verdure
# Nome Piatto not found:
# Polpette di verdure
# Nome Piatto not found:
# Polpette di verdure
# Nome Piatto not found:
# Polpette di verdure
# Nome Piatto not found:
# Polpette di verdure
# Nome Piatto not found:
# Polpette di verdure
# Nome Piatto not found:
# Polpette di verdure
# Nome Piatto not found:
# Polpette di verdure
# Nome Piatto not found:
# Polpette di verdure
# Nome Piatto not found:
# Polpette di verdure
# Nome Piatto not found:
# Polpette di verdure
# Nome Piatto not found:
# Polpette di verdure
# Nome Piatto not found:
# Polpette di verdure
# Nome Piatto not found:
# Polpette di verdure
# Nome Piatto not found:
# Focaccia col formaggio (di Recco)
# Nome Piatto not found:
# Focaccia col formaggio (di Recco)
# Nome Piatto not found:
# Focaccia col formaggio (di Recco)
# Nome Piatto not found:
# Focaccia col formaggio (di Recco)
# Nome Piatto not found:
# Focaccia col formaggio (di Recco)
# Nome Piatto not found:
# Focaccia col formaggio (di Recco)
# Nome Piatto not found:
# Torta di ciliegie
# Nome Piatto not found:
# Torta di ciliegie
# Nome Piatto not found:
# Torta di ciliegie
# Nome Piatto not found:
# Torta di ciliegie
# Nome Piatto not found:
# Torta di ciliegie
# Nome Piatto not found:
# Torta di ciliegie
# Nome Piatto not found:
# Torta di ciliegie
# Nome Piatto not found:
# Confettura di albicocche
# Nome Piatto not found:
# Confettura di albicocche
# Nome Piatto not found:
# Confettura di albicocche
# Nome Piatto not found:
# Seppie con piselli
# Nome Piatto not found:
# Seppie con piselli
# Nome Piatto not found:
# Seppie con piselli
# Nome Piatto not found:
# Seppie con piselli
# Nome Piatto not found:
# Seppie con piselli
# Nome Piatto not found:
# Seppie con piselli
# Nome Piatto not found:
# Seppie con piselli
# Nome Piatto not found:
# Seppie con piselli
# Nome Piatto not found:
# Seppie con piselli
# Nome Piatto not found:
# Seppie con piselli
# Nome Piatto not found:
# Torta Mars
# Nome Piatto not found:
# Torta Mars
# Nome Piatto not found:
# Torta Mars
# Nome Piatto not found:
# Torta Mars
# Nome Piatto not found:
# Torta Mars
# Nome Piatto not found:
# Scaloppine ai funghi
# Nome Piatto not found:
# Scaloppine ai funghi
# Nome Piatto not found:
# Scaloppine ai funghi
# Nome Piatto not found:
# Scaloppine ai funghi
# Nome Piatto not found:
# Scaloppine ai funghi
# Nome Piatto not found:
# Scaloppine ai funghi
# Nome Piatto not found:
# Scaloppine ai funghi
# Nome Piatto not found:
# Scaloppine ai funghi
# Nome Piatto not found:
# Scaloppine ai funghi
# Nome Piatto not found:
# Scaloppine ai funghi
# Nome Piatto not found:
# Pennette alla boscaiola
# Nome Piatto not found:
# Pennette alla boscaiola
# Nome Piatto not found:
# Pennette alla boscaiola
# Nome Piatto not found:
# Pennette alla boscaiola
# Nome Piatto not found:
# Pennette alla boscaiola
# Nome Piatto not found:
# Pennette alla boscaiola
# Nome Piatto not found:
# Pennette alla boscaiola
# Nome Piatto not found:
# Pennette alla boscaiola
# Nome Piatto not found:
# Pennette alla boscaiola
# Nome Piatto not found:
# Pennette alla boscaiola
# Nome Piatto not found:
# Orata al cartoccio
# Nome Piatto not found:
# Orata al cartoccio
# Nome Piatto not found:
# Orata al cartoccio
# Nome Piatto not found:
# Orata al cartoccio
# Nome Piatto not found:
# Orata al cartoccio
# Nome Piatto not found:
# Orata al cartoccio
# Nome Piatto not found:
# Orata al cartoccio
# Nome Piatto not found:
# Orata al cartoccio
# Nome Piatto not found:
# Strudel di mele
# Nome Piatto not found:
# Strudel di mele
# Nome Piatto not found:
# Strudel di mele
# Nome Piatto not found:
# Strudel di mele
# Nome Piatto not found:
# Strudel di mele
# Nome Piatto not found:
# Strudel di mele
# Nome Piatto not found:
# Strudel di mele
# Nome Piatto not found:
# Strudel di mele
# Nome Piatto not found:
# Strudel di mele
# Nome Piatto not found:
# Strudel di mele
# Nome Piatto not found:
# Strudel di mele
# Nome Piatto not found:
# Strudel di mele
# Nome Piatto not found:
# Strudel di mele
# Nome Piatto not found:
# Strudel di mele
# Nome Piatto not found:
# Strudel di mele
# Nome Piatto not found:
# Riso freddo con tonno. zucchine e limone
# Nome Piatto not found:
# Riso freddo con tonno. zucchine e limone
# Nome Piatto not found:
# Riso freddo con tonno. zucchine e limone
# Nome Piatto not found:
# Riso freddo con tonno. zucchine e limone
# Nome Piatto not found:
# Riso freddo con tonno. zucchine e limone
# Nome Piatto not found:
# Riso freddo con tonno. zucchine e limone
# Nome Piatto not found:
# Riso freddo con tonno. zucchine e limone
# Nome Piatto not found:
# Riso freddo con tonno. zucchine e limone
# Nome Piatto not found:
# Riso freddo con tonno. zucchine e limone
# Nome Piatto not found:
# Riso freddo con tonno. zucchine e limone
# Nome Piatto not found:
# Parmigiana bianca di zucchine
# Nome Piatto not found:
# Parmigiana bianca di zucchine
# Nome Piatto not found:
# Parmigiana bianca di zucchine
# Nome Piatto not found:
# Parmigiana bianca di zucchine
# Nome Piatto not found:
# Parmigiana bianca di zucchine
# Nome Piatto not found:
# Parmigiana bianca di zucchine
# Nome Piatto not found:
# Parmigiana bianca di zucchine
# Nome Piatto not found:
# Parmigiana bianca di zucchine
# Nome Piatto not found:
# Parmigiana bianca di zucchine
# Nome Piatto not found:
# Parmigiana bianca di zucchine
# Nome Piatto not found:
# Parmigiana bianca di zucchine
# Nome Piatto not found:
# Parmigiana bianca di zucchine
# Nome Piatto not found:
# Parmigiana bianca di zucchine
# Nome Piatto not found:
# Calamari ripieni
# Nome Piatto not found:
# Calamari ripieni
# Nome Piatto not found:
# Calamari ripieni
# Nome Piatto not found:
# Calamari ripieni
# Nome Piatto not found:
# Calamari ripieni
# Nome Piatto not found:
# Calamari ripieni
# Nome Piatto not found:
# Calamari ripieni
# Nome Piatto not found:
# Calamari ripieni
# Nome Piatto not found:
# Calamari ripieni
# Nome Piatto not found:
# Calamari ripieni
# Nome Piatto not found:
# Calamari ripieni
# Nome Piatto not found:
# Calamari ripieni
# Nome Piatto not found:
# Calamari ripieni
# Nome Piatto not found:
# Calamari ripieni
# Nome Piatto not found:
# Pollo alla salsa di soia
# Nome Piatto not found:
# Pollo alla salsa di soia
# Nome Piatto not found:
# Pollo alla salsa di soia
# Nome Piatto not found:
# Pollo alla salsa di soia
# Nome Piatto not found:
# Pollo alla salsa di soia
# Nome Piatto not found:
# Pollo alla salsa di soia
# Nome Piatto not found:
# Pollo alla salsa di soia
# Nome Piatto not found:
# Pollo alla salsa di soia
# Nome Piatto not found:
# Pollo alla salsa di soia
# Nome Piatto not found:
# Vellutata di zucchine
# Nome Piatto not found:
# Vellutata di zucchine
# Nome Piatto not found:
# Vellutata di zucchine
# Nome Piatto not found:
# Vellutata di zucchine
# Nome Piatto not found:
# Vellutata di zucchine
# Nome Piatto not found:
# Vellutata di zucchine
# Nome Piatto not found:
# Vellutata di zucchine
# Nome Piatto not found:
# Crostata morbida al cioccolato
# Nome Piatto not found:
# Crostata morbida al cioccolato
# Nome Piatto not found:
# Crostata morbida al cioccolato
# Nome Piatto not found:
# Crostata morbida al cioccolato
# Nome Piatto not found:
# Crostata morbida al cioccolato
# Nome Piatto not found:
# Crostata morbida al cioccolato
# Nome Piatto not found:
# Crostata morbida al cioccolato
# Nome Piatto not found:
# Crostata morbida al cioccolato
# Nome Piatto not found:
# Crostata morbida al cioccolato
# Nome Piatto not found:
# Torta Oreo
# Nome Piatto not found:
# Torta Oreo
# Nome Piatto not found:
# Torta Oreo
# Nome Piatto not found:
# Torta Oreo
# Nome Piatto not found:
# Torta Oreo
# Nome Piatto not found:
# Torta Oreo
# Nome Piatto not found:
# Torta Oreo
# Nome Piatto not found:
# Ravioli ricotta e spinaci
# Nome Piatto not found:
# Ravioli ricotta e spinaci
# Nome Piatto not found:
# Ravioli ricotta e spinaci
# Nome Piatto not found:
# Ravioli ricotta e spinaci
# Nome Piatto not found:
# Ravioli ricotta e spinaci
# Nome Piatto not found:
# Ravioli ricotta e spinaci
# Nome Piatto not found:
# Ravioli ricotta e spinaci
# Nome Piatto not found:
# Ravioli ricotta e spinaci
# Nome Piatto not found:
# Ravioli ricotta e spinaci
# Nome Piatto not found:
# Cheesecake tiramis�
# Nome Piatto not found:
# Cheesecake tiramis�
# Nome Piatto not found:
# Cheesecake tiramis�
# Nome Piatto not found:
# Cheesecake tiramis�
# Nome Piatto not found:
# Cheesecake tiramis�
# Nome Piatto not found:
# Cheesecake tiramis�
# Nome Piatto not found:
# Cheesecake tiramis�
# Nome Piatto not found:
# Cheesecake tiramis�
# Nome Piatto not found:
# Cheesecake tiramis�
# Nome Piatto not found:
# Cheesecake tiramis�
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-89-99e8512fb831> in <module>
#      13        Quantità = qty,
#      14        UM = df_ingredienti.iloc[i][2])
# ---> 15     I_Pt.save()
#      16     try:
#      17        Pt_ob=Piatti.objects.get(nome_piatto=df_ingredienti.iloc[i][3])
#
# ~/.local/lib/python3.7/site-packages/django/db/models/base.py in save(self, force_insert, force_update, using, update_fields)
#     725
#     726         self.save_base(using=using, force_insert=force_insert,
# --> 727                        force_update=force_update, update_fields=update_fields)
#     728     save.alters_data = True
#     729
#
# ~/.local/lib/python3.7/site-packages/django/db/models/base.py in save_base(self, raw, force_insert, force_update, using, update_fields)
#     763             updated = self._save_table(
#     764                 raw, cls, force_insert or parent_inserted,
# --> 765                 force_update, using, update_fields,
#     766             )
#     767         # Store the database on which the object was saved
#
# ~/.local/lib/python3.7/site-packages/django/db/models/base.py in _save_table(self, raw, cls, force_insert, force_update, using, update_fields)
#     866
#     867             returning_fields = meta.db_returning_fields
# --> 868             results = self._do_insert(cls._base_manager, using, fields, returning_fields, raw)
#     869             if results:
#     870                 for value, field in zip(results[0], returning_fields):
#
# ~/.local/lib/python3.7/site-packages/django/db/models/base.py in _do_insert(self, manager, using, fields, returning_fields, raw)
#     906         return manager._insert(
#     907             [self], fields=fields, returning_fields=returning_fields,
# --> 908             using=using, raw=raw,
#     909         )
#     910
#
# ~/.local/lib/python3.7/site-packages/django/db/models/manager.py in manager_method(self, *args, **kwargs)
#      83         def create_method(name, method):
#      84             def manager_method(self, *args, **kwargs):
# ---> 85                 return getattr(self.get_queryset(), name)(*args, **kwargs)
#      86             manager_method.__name__ = method.__name__
#      87             manager_method.__doc__ = method.__doc__
#
# ~/.local/lib/python3.7/site-packages/django/db/models/query.py in _insert(self, objs, fields, returning_fields, raw, using, ignore_conflicts)
#    1268         query = sql.InsertQuery(self.model, ignore_conflicts=ignore_conflicts)
#    1269         query.insert_values(fields, objs, raw=raw)
# -> 1270         return query.get_compiler(using=using).execute_sql(returning_fields)
#    1271     _insert.alters_data = True
#    1272     _insert.queryset_only = False
#
# ~/.local/lib/python3.7/site-packages/django/db/models/sql/compiler.py in execute_sql(self, returning_fields)
#    1414         with self.connection.cursor() as cursor:
#    1415             for sql, params in self.as_sql():
# -> 1416                 cursor.execute(sql, params)
#    1417             if not self.returning_fields:
#    1418                 return []
#
# ~/.local/lib/python3.7/site-packages/django/db/backends/utils.py in execute(self, sql, params)
#      96     def execute(self, sql, params=None):
#      97         with self.debug_sql(sql, params, use_last_executed_query=True):
# ---> 98             return super().execute(sql, params)
#      99
#     100     def executemany(self, sql, param_list):
#
# ~/.local/lib/python3.7/site-packages/django/db/backends/utils.py in execute(self, sql, params)
#      64
#      65     def execute(self, sql, params=None):
# ---> 66         return self._execute_with_wrappers(sql, params, many=False, executor=self._execute)
#      67
#      68     def executemany(self, sql, param_list):
#
# ~/.local/lib/python3.7/site-packages/django/db/backends/utils.py in _execute_with_wrappers(self, sql, params, many, executor)
#      73         for wrapper in reversed(self.db.execute_wrappers):
#      74             executor = functools.partial(wrapper, executor)
# ---> 75         return executor(sql, params, many, context)
#      76
#      77     def _execute(self, sql, params, *ignored_wrapper_args):
#
# ~/.local/lib/python3.7/site-packages/django/db/backends/utils.py in _execute(self, sql, params, *ignored_wrapper_args)
#      82                 return self.cursor.execute(sql)
#      83             else:
# ---> 84                 return self.cursor.execute(sql, params)
#      85
#      86     def _executemany(self, sql, param_list, *ignored_wrapper_args):
#
# ~/.local/lib/python3.7/site-packages/django/db/backends/sqlite3/base.py in execute(self, query, params)
#     421             return Database.Cursor.execute(self, query)
#     422         query = self.convert_query(query)
# --> 423         return Database.Cursor.execute(self, query, params)
#     424
#     425     def executemany(self, query, param_list):
#
# KeyboardInterrupt:

# %%
Ingrediente.objects.all().delete()
Ingrediente_Piatto.objects.all().delete()
Piatti.objects.all().delete()
# Out:
# (1491, {'dieta.Piatti': 1491})
